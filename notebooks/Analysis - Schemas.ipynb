# %% [markdown]
# ### Schemas
#
# Federally-hosted schemas? (Where are we getting these objects?)
#
# Linkrot
#
# (processing code found in the "XML Schema Identification and Statistics" IPy.)
#
#
# Of 509,608 parsed XML responses, 124,769 contained a schema reference.
#
# We have three sets of schema data - the references as pulled from the XML (noting that the @schemaLocation and @noNamespaceSchemaLocation attributes can have multiple, space-delimtied references), the references as individual URIs (split on the whitespace), and a list of federally-hosted schemas.
#
# Note: these were automatically extracted but underwent some minor manual cleanup (in some cases, the space was obviously missing).

# %%
# %matplotlib inline
import pandas as pd
import json as js  # name conflict with sqla
import sqlalchemy as sqla
from sqlalchemy.orm import sessionmaker
from IPython.display import display

# %%
# grab the clean text from the rds
with open('../local/big_rds.conf', 'r') as f:
    conf = js.loads(f.read())

# our connection
engine = sqla.create_engine(conf.get('connection'))

# %%
# the original, extracted schema references
with open('outputs/unique_packed_schemas_sorted.txt', 'r') as f:
    original_schemas = [s.strip() for s in f.readlines() if s]
original_schemas
# Out:
# ['../../../OGC/gml/3.2.1/gml.xsd',
#  '../../../OGC/iso/19139/20070417/gmd/gmd.xsd',
#  '../../../OGC/om/1.0.1/om.xsd',
#  '../../../OGC/sweCommon/1.0.2/swe.xsd',
#  '../../../general-component-schema.xsd',
#  '../../appinfo/2.0/appinfo.xsd',
#  '../../common/1.0/common.xsd',
#  '../../dei/2012/dei-2012-01-31.xsd',
#  '../../general-component-schema.xsd',
#  '../../gml/3.1.1/base/gml.xsd',
#  '../../structures/2.0/structures.xsd',
#  '../../xlink/1.0.0/xlinks.xsd',
#  '../common/UBL-CommonBasicComponents-2.0.xsd',
#  '../common/UBL-CommonExtensionComponents-2.0.xsd',
#  '../common/ws_common_1_0b.xsd',
#  '../fgdc-std-001-1998/fgdc-std-001-1998-ann.xsd',
#  '../gco/gco.xsd',
#  '../general-component-schema.xsd',
#  '../gmd/gmd.xsd',
#  '../napm/napmCharacterString.xsd',
#  '../schema/frame.xsd',
#  './aggregateTypes.xsd',
#  './basicTypes.xsd',
#  './encoding.xsd',
#  './simpleTypes.xsd',
#  './types.xsd',
#  '/data /finance/disclosure/schema/AdminFine.xsd',
#  '/data /finance/disclosure/schema/Leadership.xsd',
#  '/data /finance/disclosure/schema/LobbyistBundle.xsd',
#  '/schema/folder.xsd',
#  '/schemas/INF_AlmanacData_V01.02.xsd',
#  '0/WQX_WQX_v2.0.xsd',
#  'ADWR20140815.xsd',
#  'AccessControlServiceMessages.xsd',
#  'AdjacencyTable.xsd',
#  'AdministrationServiceMessages.xsd',
#  'AuthenticationServiceMessages.xsd',
#  'BasicTypes.xsd',
#  'BooleanControls.xsd',
#  'CFStandardNameTable-1.1.xsd',
#  'CalendarServiceMessages.xsd',
#  'CatalogServiceMessages.xsd',
#  'Charts.xsd',
#  'Comments.xsd',
#  'CommonTypes.xsd',
#  'CoreVocabularyAggregateComponents-v1.00.xsd',
#  'CoreVocabularyBasicComponents-v1.00.xsd',
#  'D:\\\\XML\\\\Hydroml.xsd',
#  'DD8723-5-DCTerms.xsd',
#  'DR_sections.xsd',
#  'Decisions.xsdDiscussions.xsd',
#  'EDXL-RMCommonTypes.xsd',
#  'EchoExceptions.xsd',
#  'Equipment.xsd',
#  'EventNotificationServiceMessages.xsd',
#  'EventSinkMessages.xsd',
#  'ExtendedServicesServiceMessages.xsd',
#  'ForzaLavoroLiguria.xsd',
#  'GranuleProvenance.xsd',
#  'Group2ManagementServiceMessages.xsd',
#  'HVCRMethods.xsd',
#  'HeliocentricTrajectoriesService_schema1.xsd',
#  'HorizontalControl.xsd',
#  'HydroXC.xsd',
#  'INSPIRE http://www.newcastle-staffs.gov.uk:8080/geoserver/inspire/wfs?service=WFS&version=1.0.0&request=DescribeFeatureType&typeName=inspire%3ASMOKE_CONTROL_ZONES http://www.opengis.net/wfs http://www.newcastle-staffs.gov.uk:8080/geoserver/schemas/wfs/1.0.0/WFS-basic.xsd',
#  'Junctions.xsd',
#  'Metadata.xsd',
#  'MetadataCommon.xsd',
#  'OccupatiLiguria.xsd',
#  'OrderFulfillmentFaults.xsd',
#  'OrderFulfillmentMessages.xsd',
#  'OrderFulfillmentTypes.xsd',
#  'OrderManagementServiceMessages.xsd',
#  'OrderProcessingServiceMessages.xsd',
#  'PI_Tasks.xsd',
#  'PKTDSegurConfiguration.xsd',
#  'PKTDSegurDynn.xsd',
#  'ProviderServiceMessages.xsd',
#  'Roster.xsd',
#  'SchedulingPeriod-3.0.xsd',
#  'SensitivityAnalysisService?xsd=xsd0.xsd',
#  'ServiceManagementServiceMessages.xsd',
#  'SteadyStateService?xsd=xsd0.xsd',
#  'SubscriptionServiceMessages.xsd',
#  'SurveyStatistics.xsd',
#  'TaxonomyServiceMessages.xsd',
#  'TimeCourseService?xsd=xsd0.xsd',
#  'TypeLibrary-array.xsd',
#  'TypeLibrary-list.xsd',
#  'TypeLibrary-math.xsd',
#  'TypeLibrary-quantity.xsd',
#  'TypeLibrary-text.xsd',
#  'Uncertainty.xsd',
#  'UserServiceMessages.xsd',
#  'VerticalControl.xsd',
#  'WHU-LIESMARS-WPS?xsd=ws.xsd',
#  '\\t\\thttp://www.fgdc.gov/framework/geodeticControl http://maps.sco.wisc.edu/cgi-bin/fullwfs3.pl?service=wfs&version=1.0.0&request=DescribeFeatureType',
#  'area-type-table-1.1.xsd',
#  'cgiUtilities.xsd',
#  'civil-wedding-and-civil-partnership-venue-approvals.xsd',
#  'classes.xsd',
#  'cmdi-virtual-collection.xsd',
#  'comments.xsd',
#  'counter4_0.xsd',
#  'counter4_1.xsd',
#  'counterElements3_0.xsd',
#  'counterElements4_0.xsd',
#  'counterElements4_1.xsd',
#  'currency-ent-all-draft-2014-01-31.xsd',
#  'datatypes.xsd',
#  'dc.xsd',
#  'dcterms.xsd',
#  'ddi:codebook:2_5 http://www.ddialliance.org/Specification/DDI-Codebook/2.5/XMLSchema/codebook.xsd',
#  'ddi:instance:3_0 instance.xsd',
#  'ddi:instance:3_2 file:/C:/Schemas/DDI_3_2_2013_11_13/schema/instance.xsd',
#  'ddi:instance:3_2 http://www.ddialliance.org/Specification/DDI-Lifecycle/3.2/XMLSchema/instance.xsd',
#  'dei-ent-all-draft-2014-01-31.xsd',
#  'dkcoin.xsd',
#  'eap-metadata.xsd',
#  'earthMaterial.xsd',
#  'earthresourceml.xsd',
#  'efetch.xsd',
#  'efetch_db_gene.xsd',
#  'efetch_db_nlmc.xsd',
#  'efetch_db_omim.xsd',
#  'efetch_db_pmc.xsd',
#  'efetch_db_seq.xsd',
#  'efetch_db_snp.xsd',
#  'efetch_db_taxon.xsd',
#  'egquery.xsd',
#  'einfo.xsd',
#  'elink.xsd',
#  'eml://ecoinformatics.org/eml-2.0.0 http://www.hubbardbrook.org/eml/eml-2.0.0/eml.xsd',
#  'eml://ecoinformatics.org/eml-2.0.1 eml.xsd',
#  'eml://ecoinformatics.org/eml-2.0.1 http://gce-lter.marsci.uga.edu/lter/files/schemas/eml-201/eml.xsd',
#  'eml://ecoinformatics.org/eml-2.0.1 http://io.diamond.fiu.edu/metadata/schema/eml-2.0.1/eml.xsd',
#  'eml://ecoinformatics.org/eml-2.0.1 http://www.hubbardbrook.org/eml/eml-2.0.1/eml.xsd',
#  'eml://ecoinformatics.org/eml-2.1.0 eml.xsd',
#  'eml://ecoinformatics.org/eml-2.1.0 http://data.gios.asu.edu/eml2_1_0/eml.xsd',
#  'eml://ecoinformatics.org/eml-2.1.0 http://gce-lter.marsci.uga.edu/public/files/schemas/eml-210/eml.xsd',
#  'eml://ecoinformatics.org/eml-2.1.0 http://nis.lternet.edu/schemas/EML/eml-2.1.0/eml.xsd',
#  'eml://ecoinformatics.org/eml-2.1.1 eml.xsd',
#  'eml://ecoinformatics.org/eml-2.1.1 http://rs.gbif.org/schema/eml-gbif-profile/1.0.1/eml.xsd',
#  'eml://ecoinformatics.org/eml-2.1.1 http://rs.gbif.org/schema/eml-gbif-profile/1.0.2/eml.xsd',
#  'eml://ecoinformatics.org/lter-project-2.1.0 http://gce-lter.marsci.uga.edu/public/files/schemas/project-eml-210/lter-project.xsd',
#  'erxl.xsd',
#  'esearch.xsd',
#  'espell.xsd',
#  'esummary.xsd',
#  'eurofxref.xsd',
#  'file:///E:/SW/moon/im/fgdc-std-001-1998-ann.xsd',
#  'file:/home/dietuyt/svn/clarin/metadata/trunk/toolkit/general-component-schema.xsd',
#  'ftp://ftp.sra.ebi.ac.uk/meta/xsd/sra_1_3/SRA.run.xsd',
#  'ftp://ftp.sra.ebi.ac.uk/meta/xsd/sra_1_5/SRA.experiment.xsd',
#  'ftp://ftp.sra.ebi.ac.uk/meta/xsd/sra_1_5/SRA.run.xsd',
#  'ftp://ftp.sra.ebi.ac.uk/meta/xsd/sra_1_5/SRA.sample.xsd',
#  'ftp://ftp.sra.ebi.ac.uk/meta/xsd/sra_1_5/SRA.study.xsd',
#  'ftp://ftp.sra.ebi.ac.uk/meta/xsd/sra_1_5/SRA.submission.xsd',
#  'gambling-permits.xsd',
#  'gambling-premises-licences.xsd',
#  'geo-oasis.xsd',
#  'geosciml-core.xsd',
#  'ghodata.xsd',
#  'gml-ish.xsd',
#  'http:///jpa2/javax/persistence.ecore platform:/plugin/eu.artist.migration.umlprofilestore/umlprofiles/jpa2_profile.profile.uml#_TEHZ9SWxEeOCj6LiK5WXEg',
#  'http://127.0.0.1:8080/helloservice/HelloService/__container$publishing$subctx/WEB-INF/wsdl/HelloService_schema1.xsd',
#  'http://adn.dlese.org http://www.dlese.org/Metadata/adn-item/0.6.50/record.xsd',
#  'http://adn.dlese.orghttp://www.dlese.org/Metadata/adn-item/0.6.50/record.xsd',
#  'http://ads.ahds.ac.uk/XMLschema/ \\t\\t\\thttp://ads.ahds.ac.uk/XMLschema/ads_dc.xsd',
#  'http://air-climate.eionet.europa.eu/schemas/AirQualityQuestionnaire/AirQualityQuestionnaire-form4.xsd',
#  'http://ands.org.au/standards/rif-cs/registryObjects http://services.ands.org.au/documentation/rifcs/1.2.0/schema/registryObjects.xsd',
#  'http://ands.org.au/standards/rif-cs/registryObjects http://services.ands.org.au/home/orca/schemata/registryObjects.xsd',
#  'http://anss-sis.scsn.org/xml/ext-stationxml/2.0 http://anss-sis.scsn.org/xml/ext-stationxml/2.0/sis_extension.xsd',
#  'http://api.bioinfo.no/schema/BlastOutput.xsd',
#  'http://api.bioinfo.no/schema/BlastParameters.xsd',
#  'http://api.bioinfo.no/schema/ELM.xsd',
#  'http://api.bioinfo.no/schema/ELMInstancePrediction.xsd',
#  'http://api.bioinfo.no/schema/Jaspar_matrix_0.2.xsd',
#  'http://apps.who.int/gho/athena/data/GHO/CM_01,CM_02,CM_03,DEVICES09,DEVICES22,HIV_0000000020,MALARIA001,MDG_0000000001,MDG_0000000003,MDG_0000000005,MDG_0000000005_AGE1519,MDG_0000000006,MDG_0000000006_AGE1519,MDG_0000000007,MDG_0000000010,MDG_0000000011,MDG_0000000013,MDG_0000000014,MDG_0000000017,MDG_0000000020,MDG_0000000023,MDG_0000000025,MDG_0000000025_AGE1519,MDG_0000000026,MDG_0000000029,MDG_0000000031,MDG_0000000033,MDG_0000000034,MH_17,MH_18,MH_6,SA_0000001688,TB_1,TB_tot_newrel,TOBACCO_0000000192,WHOSIS_000001,WHOSIS_000003,WHOSIS_000005,WHOSIS_000011,WHOSIS_000015,WHS10_1,WHS10_8,WHS10_9,WHS2_138,WHS2_162,WHS2_163,WHS2_164,WHS2_165,WHS2_166,WHS2_167,WHS2_168,WHS2_170,WHS2_171,WHS2_172,WHS2_173,WHS2_174,WHS2_3070_all,WHS2_3070_cancer,WHS2_3070_cdd,WHS2_3070_chronic,WHS2_513,WHS2_514,WHS2_515,WHS2_516,WHS2_523,WHS3_40,WHS3_41,WHS3_42,WHS3_43,WHS3_45,WHS3_46,WHS3_47,WHS3_48,WHS3_49,WHS3_50,WHS3_51,WHS3_52,WHS3_53,WHS3_55,WHS3_56,WHS3_57,WHS3_62,WHS4_100,WHS4_106,WHS4_107,WHS4_108,WHS4_111,WHS4_111_AGE1519,WHS4_115,WHS4_117,WHS4_124,WHS4_128,WHS4_129,WHS4_154,WHS4_2530,WHS6_101,WHS6_102,WHS6_116,WHS6_123,WHS6_125,WHS6_127,WHS6_136,WHS6_140,WHS6_144,WHS6_148,WHS6_150,WHS6_517,WHS6_518,WHS6_519,WHS6_520,WHS7_103,WHS7_104,WHS7_105,WHS7_108,WHS7_113,WHS7_120,WHS7_134,WHS7_139,WHS7_143,WHS7_147,WHS7_149,WHS7_156,WHS8_110,WHS9_85,WHS9_86,WHS9_88,WHS9_89,WHS9_90,WHS9_91,WHS9_92,WHS9_93,WHS9_95,WHS9_96,WHS9_97,WHS9_CBR,WHS9_CDR,WHS9_CS.xsd?format=xml&profile=simple-schema',
#  'http://apps.who.int/gho/athena/data/GHO/HIV_0000000001.xsd?format=xml&profile=simple-schema',
#  'http://apps.who.int/gho/athena/data/GHO/MORT_100.xsd?format=xml&profile=simple-schema',
#  'http://apps.who.int/gho/athena/xmart/EBOLA_MEASURE/CASES.xsd?format=xml&profile=simple-schema',
#  'http://arno.uvt.nl/xsd/1.2/arno/ http://arno.uvt.nl/xsd/1.2/arno.xsd',
#  'http://aviationweather.gov/adds/schema/aircraftreport1_0.xsd',
#  'http://aviationweather.gov/adds/schema/airsigmet1_1.xsd',
#  'http://aviationweather.gov/adds/schema/gairmet1_0.xsd',
#  'http://aviationweather.gov/adds/schema/metar1_2.xsd',
#  'http://aviationweather.gov/adds/schema/pirep1_2.xsd',
#  'http://aviationweather.gov/adds/schema/taf1_2.xsd',
#  'http://biodiversity.eionet.europa.eu/schemas/bernconvention/derogations.xsd',
#  'http://bioputer.mimuw.edu.pl:8080/tav4sb/services?xsd=add.xsd',
#  'http://bioputer.mimuw.edu.pl:8080/tav4sb/services?xsd=mathematica.xsd',
#  'http://bioputer.mimuw.edu.pl:8080/tav4sb/services?xsd=odesolver.xsd',
#  'http://bioputer.mimuw.edu.pl:8080/tav4sb/services?xsd=prism.xsd',
#  'http://bioware.ucd.ie:8080/soaplab2/typed/services/custom.slimfinder?xsd=1',
#  'http://bioware.ucd.ie:8080/soaplab2/typed/services/custom.slimfinder?xsd=3',
#  'http://bison.ijs.si/WebServices/TextNet.svc?xsd=xsd0',
#  'http://bison.ijs.si/WebServices/TextNet.svc?xsd=xsd1',
#  'http://bison.ijs.si/WebServices/TextNet.svc?xsd=xsd2',
#  'http://bison.ijs.si/WebServices/TextNet.svc?xsd=xsd3',
#  'http://bison.ijs.si/WebServices/TextNet.svc?xsd=xsd4',
#  'http://bison.ijs.si/WebServices/TextNet.svc?xsd=xsd5',
#  'http://brg.ldeo.columbia.edu/services/LogFile.xsd',
#  'http://brg.ldeo.columbia.edu/services/LogHole.xsd',
#  'http://capec.mitre.org/data/xsd/attack_taxonomy_schema_v1.1.1.xsd',
#  'http://carocoops.org/obskml/1.0.0/obs_types.xsd',
#  'http://carocoops.org/obskml/1.0.0/uom_types.xsd',
#  'http://chipster.csc.fi:80/chipster-ws/chipster?xsd=1',
#  'http://code.google.com/apis/kml/schema/kml21.xsd',
#  'http://collection.dlese.orghttp://www.dlese.org/Metadata/collection/0.1.01/collection.xsd',
#  'http://collection.dlese.orghttp://www.dlese.org/Metadata/collection/1.0.00/collection.xsd',
#  'http://conscore.embl.de/webservice/schema/ConScorePrediction.xsd',
#  'http://data.nodc.noaa.gov/coris/data/CoRIS/fgdc_schema_coris/fgdc-std-001-1998.xsd',
#  'http://data.usgs.gov/nggdpp/NGGDPPMetadataSample_v2.xsd',
#  'http://datacite.org/schema/kernel-2.2 http://schema.datacite.org/meta/kernel-2.2/metadata.xsd',
#  'http://datacite.org/schema/kernel-3 http://schema.datacite.org/meta/kernel-3/metadata.xsd',
#  'http://dataconservancy.org/schemas/bop/1.0',
#  'http://dd.eionet.europa.eu/schemas/fgases-2015/FGasesReporting.xsd',
#  'http://dd.eionet.europa.eu/schemas/habides-2.0/derogations.xsd',
#  'http://dd.eionet.europa.eu/schemas/mmr-pams/MMR_PAMs.xsd',
#  'http://dd.eionet.europa.eu/schemaset/id2011850eu-1.0 http://dd.eionet.europa.eu/schemas/id2011850eu-1.0/AirQualityReporting.xsd',
#  'http://digir.sourceforge.net/schema/conceptual/darwin/2003/1.0/darwin2.xsd',
#  'http://diglib.org/ilsdi/1.1 http://www.diglib.org/architectures/ilsdi/schemas/1.1/dlfexpanded.xsd',
#  'http://docs.oasis-open.org/search-ws/ searchRetrieve/v1.0/csd01/schemas/diagnostic.xsd',
#  'http://docs.oasis-open.org/search-ws/ searchRetrieve/v1.0/csd01/schemas/facetedResults.xsd',
#  'http://docs.oasis-open.org/search-ws/ searchRetrieve/v1.0/csd01/schemas/scan.xsd',
#  'http://docs.oasis-open.org/search-ws/ searchRetrieve/v1.0/csd01/schemas/searchResultAnalysis.xsd',
#  'http://docs.oasis-open.org/search-ws/ searchRetrieve/v1.0/csd01/schemas/xcql.xsd',
#  'http://docs.oasis-open.org/security/saml/v2.0/saml-schema-protocol-2.0.xsd',
#  'http://docs.oasis-open.org/wsrf/bf-2.xsd',
#  'http://docs.oasis-open.org/wsrf/rl-2.xsd',
#  'http://docs.oasis-open.org/xacml/2.0/access_control-xacml-2.0-context-schema-os.xsd',
#  'http://docs.oasis-open.org/xacml/2.0/access_control-xacml-2.0-policy-schema-os.xsd',
#  'http://docs.oasis-open.org/xacml/3.0/xacml-1.0-profile-saml2.0-v2-schema-assertion-wd-13.xsd',
#  'http://docs.rioxx.net/schema/v1.0/rioxxterms/ http://docs.rioxx.net/schema/v1.0/rioxxterms.xsd',
#  'http://docs.rioxx.net/schema/v2.0/rioxxterms/ http://docs.rioxx.net/schema/v2.0/rioxxterms.xsd',
#  'http://dublincore.org/schemas/xmls/qdc/2003/04/02/dc.xsd',
#  'http://dublincore.org/schemas/xmls/qdc/2003/04/02/dcterms.xsd',
#  'http://dublincore.org/schemas/xmls/qdc/2008/02/11/dcterms.xsd',
#  'http://dublincore.org/schemas/xmls/qdc/dc.xsd',
#  'http://dublincore.org/schemas/xmls/simpledc20021212.xsd',
#  'http://dublincore.org/xml/dc-dsp/2008/01/14 http://dublincore.org/architecturewiki/DescriptionSetProfile?action=AttachFile&do=get&target=dcmi-dsp.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/AnalysisFractionXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/AnalysisImageXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/InitialPbModelETXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/InitialPbModelXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/MineralStandardModelXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/MineralStandardUPbModelXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/PbBlankICModelXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/PbBlankXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/PhysicalConstantsModelXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/PhysicalConstantsXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/ReduxMatrixXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/TracerUPbModelXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/TracerXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/ValueModelXMLSchema.xsd',
#  'http://earthquake.usgs.gov http://earthquake.usgs.gov/eqcenter/shakemap/xml/schemas/shakemap.xsd',
#  'http://earthquake.usgs.gov http://earthquake.usgs.gov/shakemap/xml/schemas/shakemap.xsd',
#  'http://echo.nasa.gov/v9/echoforms http://api.echo.nasa.gov/echo/wsdl/EchoForms.xsd',
#  'http://enm.eubrazilopenbio.d4science.org:80/om/omws?xsd=1',
#  'http://enunciate.codehaus.org/schemas/enunciate-1.29.xsd',
#  'http://europass.cedefop.europa.eu/Europass http://europass.cedefop.europa.eu/xml/EuropassSchema_V3.0.xsd',
#  'http://europass.cedefop.europa.eu/Europass/V2.0 http://europass.cedefop.europa.eu/xml/EuropassSchema_V2.0.xsd',
#  'http://fgdcxml.sourceforge.net/schema/fgdc-std-012-2002/fgdc-std-012-2002.xsd',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/ http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/dif.xsd',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/ http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/dif_v9.4.xsd',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/ http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/dif_v9.7.1.xsd',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/ http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/dif_v9.8.4.xsd',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/kms/kms.xsd',
#  'http://geodata.nationaalgeoregister.nl/schemas/gml/3.2.1/gml.xsd',
#  'http://get.rvdata.us/schema/r2r-1.0 http://get.rvdata.us/schema/r2r-1.0.xsd',
#  'http://get.rvdata.us/schema/r2r-1.1 http://get.rvdata.us/schema/r2r-1.1.xsd',
#  'http://gimp-print.sourceforge.net/xsd/gp.xsd-1.0 gutenprint.xsd',
#  'http://gnode1.mib.man.ac.uk:8080/FullTextWebServices/ArticleSectionClassifierService?xsd=1',
#  'http://gnode1.mib.man.ac.uk:8080/FullTextWebServices/FindingRelationshipsService?xsd=1',
#  'http://gnode1.mib.man.ac.uk:8080/FullTextWebServices/FindingThingsService?xsd=1',
#  'http://gnode1.mib.man.ac.uk:8080/FullTextWebServices/PdfToTextService?xsd=1',
#  'http://gnode1.mib.man.ac.uk:8080/FullTextWebServices/SentenceSplitterService?xsd=1',
#  'http://gnode1.mib.man.ac.uk:8080/FullTextWebServices/TextCleanerService?xsd=1',
#  'http://graphical.weather.gov/xml/DWMLgen/schema/DWML.xsd',
#  'http://graphical.weather.gov/xml/DWMLgen/schema/meta_data.xsd',
#  'http://graphical.weather.gov/xml/DWMLgen/schema/ndfd_data.xsd',
#  'http://graphml.graphdrawing.org/xmlns http://graphml.graphdrawing.org/xmlns/1.0/graphml.xsd',
#  'http://hdf.ncsa.uiuc.edu/DTDs/HDF5File http://hdf.ncsa.uiuc.edu/DTDs/HDF5-File.xsd',
#  'http://hdfgroup.org/DTDs/HDF5-File http://www.hdfgroup.org/DTDs/HDF5-File.xsd',
#  'http://hesapi.lbl.gov/mf_api/xsd/add_lu_schedule_obj',
#  'http://hesapi.lbl.gov/mf_api/xsd/calculate',
#  'http://hesapi.lbl.gov/mf_api/xsd/doe2sim',
#  'http://hesapi.lbl.gov/mf_api/xsd/nearest_weather',
#  'http://hesapi.lbl.gov/mf_api/xsd/retrieve_results',
#  'http://hesapi.lbl.gov/mf_api/xsd/retrofit',
#  'http://hesapi.lbl.gov/mf_api/xsd/submit',
#  'http://hesapi.lbl.gov/mf_api/xsd/submit_dhw_water_heater',
#  'http://hesapi.lbl.gov/st_api/xsd/archive_buildings_by_id',
#  'http://hesapi.lbl.gov/st_api/xsd/building_ca_id',
#  'http://hesapi.lbl.gov/st_api/xsd/calc_energy_multi',
#  'http://hesapi.lbl.gov/st_api/xsd/calculate',
#  'http://hesapi.lbl.gov/st_api/xsd/delete_buildings_by_id',
#  'http://hesapi.lbl.gov/st_api/xsd/doe2sim',
#  'http://hesapi.lbl.gov/st_api/xsd/export_label_results',
#  'http://hesapi.lbl.gov/st_api/xsd/generate_label',
#  'http://hesapi.lbl.gov/st_api/xsd/login_lbl',
#  'http://hesapi.lbl.gov/st_api/xsd/register_qa',
#  'http://hesapi.lbl.gov/st_api/xsd/retrieve_buildings_by_address',
#  'http://hesapi.lbl.gov/st_api/xsd/retrieve_buildings_by_id',
#  'http://hesapi.lbl.gov/st_api/xsd/retrieve_extended_results',
#  'http://hesapi.lbl.gov/st_api/xsd/retrieve_inputs',
#  'http://hesapi.lbl.gov/st_api/xsd/retrieve_label_results',
#  'http://hesapi.lbl.gov/st_api/xsd/retrieve_legacy_buildings',
#  'http://hesapi.lbl.gov/st_api/xsd/retrieve_recommendations',
#  'http://hesapi.lbl.gov/st_api/xsd/retrieve_results',
#  'http://hesapi.lbl.gov/st_api/xsd/submit_address',
#  'http://hesapi.lbl.gov/st_api/xsd/submit_inputs',
#  'http://hesapi.lbl.gov/st_api/xsd/user_exists',
#  'http://hesapi.lbl.gov/st_api/xsd/validate_inputs',
#  'http://hul.harvard.edu/ois/xml/ns/drs/audioCreatorSchema.html http://hul.harvard.edu/ois/xml/xsd/drs/audioCreator.xsd',
#  'http://hul.harvard.edu/ois/xml/ns/jhove http://hul.harvard.edu/ois/xml/xsd/jhove/1.5/jhove.xsd',
#  'http://i-lab.mit.edu http://web.mit.edu/6.302/www/weblab/xml/experimentResult.xsd',
#  'http://i-lab.mit.edu http://web.mit.edu/6.302/www/weblab/xml/experimentRoutine.xsd',
#  'http://i-lab.mit.edu http://web.mit.edu/6.302/www/weblab/xml/experimentSpecification.xsd',
#  'http://i-lab.mit.edu http://web.mit.edu/6.302/www/weblab/xml/labConfiguration.xsd',
#  'http://igsaaahmvsw001/waterportal/fgdc-std-001-1998.xsd',
#  'http://inspire.ec.europa.eu/codelist_register/codelist http://inspire.ec.europa.eu/draft-schemas/registry/1.0/CodeList.xsd',
#  'http://inspire.ec.europa.eu/codelist_register/codelist/item http://inspire.ec.europa.eu/draft-schemas/registry/1.0/CodeListValue.xsd',
#  'http://inspire.ec.europa.eu/draft-schemas/registry/0.3/codelist.xsd',
#  'http://inspire.ec.europa.eu/featureconcept_register/featureconcept http://inspire.ec.europa.eu/draft-schemas/registry/1.0/FeatureConcept.xsd',
#  'http://inspire.ec.europa.eu/metadata-codelist_register/metadata-codelist http://inspire.ec.europa.eu/draft-schemas/registry/1.0/MetadataCodeList.xsd',
#  'http://inspire.ec.europa.eu/metadata-codelist_register/metadata-codelist/item http://inspire.ec.europa.eu/draft-schemas/registry/1.0/MetadataCodeListValue.xsd',
#  'http://inspire.ec.europa.eu/schemas/au/3.0/AdministrativeUnits.xsd',
#  'http://inspire.ec.europa.eu/schemas/base/3.2/BaseTypes.xsd',
#  'http://inspire.ec.europa.eu/schemas/gn/3.0/GeographicalNames.xsd',
#  'http://inspire.ec.europa.eu/schemas/inspire_ds/1.0 http://inspire.ec.europa.eu/schemas/inspire_ds/1.0/inspire_ds.xsd',
#  'http://inspire.ec.europa.eu/schemas/lcr/3.0rc3 http://inspire.ec.europa.eu/draft-schemas/lcr/3.0rc3/LandCoverRaster.xsd',
#  'http://inspire.jrc.ec.europa.eu/monitoringreporting/monitoring http://dd.eionet.europa.eu/schemas/inspire-monitoring/monitoring.xsd',
#  'http://isis.astrogeology.usgs.gov/Schemas/Application/application.xsd',
#  'http://isis.astrogeology.usgs.gov/Schemas/Documentation/documentation.xsd',
#  'http://iso25964.org/ file:///C:\\\\Workplan\\\\Thesaurus%20interchange%20standard\\\\iso25964-5-flat.xsd',
#  'http://jasperreports.sourceforge.net/jasperreports http://jasperreports.sourceforge.net/xsd/jasperreport.xsd',
#  'http://jasperreports.sourceforge.net/jasperreports/components http://jasperreports.sourceforge.net/xsd/components.xsd',
#  'http://java.sun.com/xml/ns/j2ee http://java.sun.com/xml/ns/j2ee/web-app_2_4.xsd',
#  'http://java.sun.com/xml/ns/j2ee http://java.sun.com/xml/ns/j2ee/web-jsptaglibrary_2_0.xsd',
#  'http://java.sun.com/xml/ns/javaee http://java.sun.com/xml/ns/javaee/web-app_2_5.xsd',
#  'http://java.sun.com/xml/ns/javaee http://java.sun.com/xml/ns/javaee/web-jsptaglibrary_2_1.xsd',
#  'http://leisp.usdoj.gov/niem/FoiaAnnualReport/exchange/1.02 ../schema/exchange/FoiaAnnualReport.xsd',
#  'http://leisp.usdoj.gov/niem/FoiaAnnualReport/exchange/1.03 ../schema/exchange/FoiaAnnualReport.xsd',
#  'http://lindat.mff.cuni.cz/ns/experimental/bibtex http://lindat.mff.cuni.cz/schemas/experimental/bibtex.xsd',
#  'http://localhost:8080/geoserver/schemas/gml/2.1.2.1/feature.xsd',
#  'http://maps.sco.wisc.edu/schemas/gc_uml20051216.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://demo.mapserver.org/cgi-bin/wfs?SERVICE=WFS&VERSION=1.0.0&REQUEST=DescribeFeatureType&TYPENAME=continents&OUTPUTFORMAT=SFE_XMLSCHEMA',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/services/ds898?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=domains&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/services/nmra?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=Porphyry_Cu&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/active-mines?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=mineplant&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/agdb2?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=agdb&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/akages-geo?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=akages&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/akgeol?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=akgeol,akfault&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/ardf?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=ardf&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/asbestos?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=asbestos&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/copper-smelters?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=cusmelters&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/digitized?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=digitized,digital&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/ds801?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=ds801&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/geochron?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=geochron&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/hi?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=units,faults,dikes&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/kb?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=Geology,Faults&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/mrds?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=mrds&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/ngdbrock?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=ngdbrock&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/ngs?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=natgeochem&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/nicrpge?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=nicrpge&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/nuresed?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=nuresed&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://mapserver.gis.umn.edu/mapserver http://mrdata.usgs.gov/wfs/nurewtr?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=nurewtr&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1 http://www.opengis.net/wfs http://schemas.opengis.net/wfs/1.1.0/wfs.xsd',
#  'http://maven.apache.org/POM/4.0.0 http://maven.apache.org/maven-v4_0_0.xsd',
#  'http://maven.apache.org/POM/4.0.0 http://maven.apache.org/xsd/maven-4.0.0.xsd',
#  'http://maven.apache.org/SETTINGS/1.0.0 http://maven.apache.org/xsd/settings-1.0.0.xsd',
#  'http://maven.apache.org/plugins/maven-archetype-plugin/archetype-catalog/1.0.0 http://maven.apache.org/xsd/archetype-catalog-1.0.0.xsd',
#  'http://mook.inf.ed.ac.uk:8848/SedMLWebService/sedmlws?xsd=1',
#  'http://myosg.grid.iu.edu/schema/rgsummary.xsd',
#  'http://naca.central.cranfield.ac.uk/ethos-oai/2.0/ http://naca.central.cranfield.ac.uk/ethos-oai/2.0/uketd_dc.xsd',
#  'http://naesb.org/espi espiDerived.xsd',
#  'http://namespace.emotion-project.eu/version/Final2.1.0/pubtrans http://www.geobilbao.net/wfsCocities/schemas/CoCities-Data-GML-Final2.2.0/eMotion/eMotionVersionFinal2.1.0-PublicTransport.xsd http://www.opengis.net/wfs http://www.geobilbao.net/wfsCocities/schemas/wfs/1.1.0/wfs.xsd',
#  'http://ngdc.noaa.gov/metadata/published/xsd/ngdcSchema/schema.xsd',
#  'http://ngdc.noaa.gov/mgg/ecs/metadata/seismic/xml/seismicMetadata.xsd',
#  'http://nrg.wustl.edu/fs https://central.xnat.org/schemas/fs/fs.xsd http://nrg.wustl.edu/workflow https://central.xnat.org/schemas/pipeline/workflow.xsd http://nrg.wustl.edu/catalog https://central.xnat.org/schemas/catalog/catalog.xsd http://nrg.wustl.edu/pipe https://central.xnat.org/schemas/pipeline/repository.xsd http://nrg.wustl.edu/scr https://central.xnat.org/schemas/screening/screeningAssessment.xsd http://nrg.wustl.edu/nunda https://central.xnat.org/schemas/nunda/nunda.xsd http://nrg.wustl.edu/arc https://central.xnat.org/schemas/project/project.xsd http://nrg.wustl.edu/cnda https://central.xnat.org/schemas/cnda_xnat/cnda_xnat.xsd http://nrg.wustl.edu/sapssans https://central.xnat.org/schemas/sapssans/sapssans.xsd http://nrg.wustl.edu/sf https://central.xnat.org/schemas/subjforms/subjforms.xsd http://nrg.wustl.edu/val https://central.xnat.org/schemas/validation/protocolValidation.xsd http://nrg.wustl.edu/xnat https://central.xnat.org/schemas/xnat/xnat.xsd http://nrg.wustl.edu/neurocog https://central.xnat.org/schemas/neurocog/neurocog.xsd http://nrg.wustl.edu/genetics https://central.xnat.org/schemas/genetics/genetics.xsd http://nrg.wustl.edu/xnat_assessments https://central.xnat.org/schemas/assessments/assessments.xsd http://www.nbirn.net/prov https://central.xnat.org/schemas/birn/birnprov.xsd http://nrg.wustl.edu/security https://central.xnat.org/schemas/security/security.xsd',
#  'http://ns.nsdl.org/nsdl_dc_v1.01 http://ns.nsdl.org/schemas/nsdl_dc/nsdl_dc_v1.01.xsd',
#  'http://ns.nsdl.org/nsdl_dc_v1.02/ http://ns.nsdl.org/schemas/nsdl_dc/nsdl_dc_v1.02.xsd',
#  'http://nvo.stsci.edu/vor10/RIStandardService.asmx?schema=schema1',
#  'http://nvo.stsci.edu/vor10/RIStandardService.asmx?schema=schema10',
#  'http://nvo.stsci.edu/vor10/RIStandardService.asmx?schema=schema11',
#  'http://nvo.stsci.edu/vor10/RIStandardService.asmx?schema=schema12',
#  'http://nvo.stsci.edu/vor10/RIStandardService.asmx?schema=schema13',
#  'http://nvo.stsci.edu/vor10/RIStandardService.asmx?schema=schema2',
#  'http://nvo.stsci.edu/vor10/RIStandardService.asmx?schema=schema3',
#  'http://nvo.stsci.edu/vor10/RIStandardService.asmx?schema=schema4',
#  'http://nvo.stsci.edu/vor10/RIStandardService.asmx?schema=schema5',
#  'http://nvo.stsci.edu/vor10/RIStandardService.asmx?schema=schema6',
#  'http://nvo.stsci.edu/vor10/RIStandardService.asmx?schema=schema7',
#  'http://nvo.stsci.edu/vor10/RIStandardService.asmx?schema=schema8',
#  'http://nvo.stsci.edu/vor10/RIStandardService.asmx?schema=schema9',
#  'http://oai.dlib.vt.edu/OAI/metadata/toolkit http://alcme.oclc.org/oaicat/toolkit.xsd',
#  'http://oai.dlib.vt.edu/OAI/metadata/toolkit http://oai.dlib.vt.edu/OAI/metadata/toolkit.xsd',
#  'http://objects.dlese.orghttp://www.dlese.org/Metadata/objects/0.1.01/objects.xsd',
#  'http://ogr.maptools.org/',
#  'http://ogr.maptools.org/ StatBez_Linz.xsd',
#  'http://ogr.maptools.org/ StatBez_Linz_EPSG_31255.xsd',
#  'http://ogr.maptools.org/ https://geo.sv.rostock.de/download/opendata/buergerschaftswahl_2014/wahlbereiche_2014.xsd',
#  'http://ogr.maptools.org/ https://geo.sv.rostock.de/download/opendata/buergerschaftswahl_2014/wahlbezirke_2014.xsd',
#  'http://ogr.maptools.org/ https://geo.sv.rostock.de/download/opendata/europaparlamentswahl_2014/wahlbezirke_2014.xsd',
#  'http://ogr.maptools.org/ https://geo.sv.rostock.de/download/opendata/fernwaermevorranggebiete/fernwaermevorranggebiete.xsd',
#  'http://ogr.maptools.org/ https://geo.sv.rostock.de/download/opendata/gemeindeflaeche/gemeindeflaeche.xsd',
#  'http://ogr.maptools.org/ https://geo.sv.rostock.de/download/opendata/geothermiepotential/geothermiepotential.xsd',
#  'http://ogr.maptools.org/ https://geo.sv.rostock.de/download/opendata/ortsamtsbereiche/ortsamtsbereiche.xsd',
#  'http://ogr.maptools.org/ https://geo.sv.rostock.de/download/opendata/schoepfwerkeinflussbereiche/schoepfwerkeinflussbereiche.xsd',
#  'http://ogr.maptools.org/ https://geo.sv.rostock.de/download/opendata/stadtbuslinien/stadtbuslinien.xsd',
#  'http://ogr.maptools.org/ https://geo.sv.rostock.de/download/opendata/strassenbahnlinien/strassenbahnlinien.xsd',
#  'http://ogr.maptools.org/ https://geo.sv.rostock.de/download/opendata/ueberschwemmungsgebiet/ueberschwemmungsgebiet.xsd',
#  'http://ogr.maptools.org/ https://geo.sv.rostock.de/download/opendata/volksentscheid_2015_stimmbezirke/volksentscheid_2015_stimmbezirke.xsd',
#  'http://ogr.maptools.org/ https://geo.sv.rostock.de/download/opendata/wahlbezirke-oberbuergermeisterwahl-2012/wahlbezirke-oberbuergermeisterwahl-2012.xsd',
#  'http://omeka.org/schemas/omeka-xml/v5 http://omeka.org/schemas/omeka-xml/v5/omeka-xml-5-0.xsd',
#  'http://open-data.europa.eu/ontologies/protocol-v2.0/odp-protocol.xsd',
#  'http://opendata.cambridgeshireinsight.org.uk/dataset/cambridgeshire-insight-open-data-inventory-list http://opendata.cambridgeshireinsight.org.uk/files/ci_opendata/inventory_v1.xsd',
#  'http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1200/dph_example_products/xml_schema/PDS4_PDS_1200.xsd',
#  'http://pds.nasa.gov/pds4/disp/v1 http://pds.nasa.gov/pds4/disp/v1/PDS4_DISP_1301.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 \\t http://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1100.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 \\thttp://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1100.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/pds4/pds/v1/PDS4_PDS_1101.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/pds4/pds/v1/PDS4_PDS_1201.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/pds4/pds/v1/PDS4_PDS_1301.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/pds4/pds/v1/PDS4_PDS_1400.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1000.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1100.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1101.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1201.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1100/dph_example_archive_VG2PLS/xml_schema/PDS4_PDS_1100.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1100/dph_example_products/xml_schema/PDS4_PDS_1100.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1100/dph_example_products/xml_schema/PDS4_PDS_1100.xsd http://pds.nasa.gov/pds4/dph/v01 http://pds.jpl.nasa.gov/repository/pds4/examples/test_0100/dph_example_dict_0100.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1100/dph_example_products/xml_schema/PDS4_PDS_1100.xsd http://pds.nasa.gov/pds4/sp/v1 PDS4_SP_1001.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1101/dph_example_archive_VG2PLS/xml_schema/PDS4_PDS_1101.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1101/dph_example_archive_VG2PLS/xml_schema/PDS4_PDS_1101.xsd http://pds.nasa.gov/pds4/dph/v01 http://pds.jpl.nasa.gov/repository/pds4/examples/test_0100/dph_example_dict_0100.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1101/dph_example_products/xml_schema/PDS4_PDS_1101.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1101/dph_example_products/xml_schema/PDS4_PDS_1101.xsd http://pds.nasa.gov/pds4/dph/v01 http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1101/dph_example_products/xml_schema/dph_example_dict_1101.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1101/dph_example_products/xml_schema/PDS4_PDS_1101.xsd http://pds.nasa.gov/pds4/sp/v1 PDS4_SP_1001.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1200/dph_example_archive_VG2PLS/xml_schema/PDS4_PDS_1200.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1200/dph_example_products/xml_schema/PDS4_PDS_1200.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1200/dph_example_products/xml_schema/PDS4_PDS_1200.xsd http://pds.nasa.gov/pds4/dph/v01 http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1200/dph_example_products/xml_schema/dph_example_dict_1200.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1200/dph_example_products/xml_schema/PDS4_PDS_1200.xsd http://pds.nasa.gov/pds4/sp/v1 PDS4_SP_1001.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/repository/pds4/examples/test_0100/PDS4_PDS_1000.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.jpl.nasa.gov/repository/pds4/examples/test_0100/PDS4_PDS_1000.xsd http://pds.nasa.gov/pds4/dph/v01 http://pds.jpl.nasa.gov/repository/pds4/examples/test_0100/dph_example_dict_0100.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1000.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1100.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1101.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1200.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1201.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1300.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1301.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1400.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1400.xsd http://pds.nasa.gov/pds4/mission/mvn/v1 http://pds.nasa.gov/pds4/mvn/v1/PDS4_MVN_1000.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1400.xsd http://pds.nasa.gov/pds4/mission/mvn/v1 http://pds.nasa.gov/pds4/mvn/v1/PDS4_MVN_1011.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1410.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1500.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1000.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1000.xsd http://pds.nasa.gov/pds4/phxmd/v02 http://atmos.nmsu.edu/pub/PDS4/schema/PHXMD_1000.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1100.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1101.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1201.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1300.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1400.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://starbase.jpl.nasa.gov/pds4/1201/dph_examples_20140625/dph_example_archive_VG2PLS/xml_schema/PDS4_PDS_1201.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://starbase.jpl.nasa.gov/pds4/1201/dph_examples_20140625/dph_example_archive_VG2PLS/xml_schema/PDS4_PDS_1201.xsd http://pds.nasa.gov/pds4/dph/v01 http://starbase.jpl.nasa.gov/pds4/1201/dph_examples_20140625/dph_example_archive_VG2PLS/xml_schema/dph_example_dict_1201.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://starbase.jpl.nasa.gov/pds4/1201/dph_examples_20140625/dph_example_products/xml_schema/PDS4_PDS_1201.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://starbase.jpl.nasa.gov/pds4/1201/dph_examples_20140625/dph_example_products/xml_schema/PDS4_PDS_1201.xsd http://pds.nasa.gov/pds4/dph/v01 http://starbase.jpl.nasa.gov/pds4/1201/dph_examples_20140625/dph_example_products/xml_schema/dph_example_dict_1201.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://starbase.jpl.nasa.gov/pds4/1300/dph_example_archive_VG2PLS/xml_schema/PDS4_PDS_1300.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://starbase.jpl.nasa.gov/pds4/1300/dph_example_archive_VG2PLS/xml_schema/PDS4_PDS_1300.xsd http://pds.nasa.gov/pds4/dph/v01 http://starbase.jpl.nasa.gov/pds4/1300/dph_example_archive_VG2PLS/xml_schema/dph_example_dict_1300.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://starbase.jpl.nasa.gov/pds4/1300/dph_example_products/xml_schema/PDS4_PDS_1300.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://starbase.jpl.nasa.gov/pds4/1300/dph_example_products/xml_schema/PDS4_PDS_1300.xsd http://pds.nasa.gov/pds4/dph/v01 http://starbase.jpl.nasa.gov/pds4/1300/dph_example_products/xml_schema/dph_example_dict_1300.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://starbase.jpl.nasa.gov/pds4/1300/dph_example_products/xml_schema/dph_example_dict_1300.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 http://starbase.jpl.nasa.gov/pds4/1400/dph_example_products/xml_schema/dph_example_dict_1400.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 https://starbase.jpl.nasa.gov/pds4/1400/dph_example_archive_VG2PLS/xml_schema/PDS4_PDS_1400.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 https://starbase.jpl.nasa.gov/pds4/1400/dph_example_archive_VG2PLS/xml_schema/PDS4_PDS_1400.xsd http://pds.nasa.gov/pds4/dph/v01 https://starbase.jpl.nasa.gov/pds4/1400/dph_example_archive_VG2PLS/xml_schema/dph_example_dict_1400.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 https://starbase.jpl.nasa.gov/pds4/1400/dph_example_products/xml_schema/PDS4_PDS_1400.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 https://starbase.jpl.nasa.gov/pds4/1400/dph_example_products/xml_schema/PDS4_PDS_1400.xsd http://pds.nasa.gov/pds4/dph/v01 https://starbase.jpl.nasa.gov/pds4/1400/dph_example_products/xml_schema/dph_example_dict_1400.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1 https://starbase.jpl.nasa.gov/pds4/1400/dph_example_products/xml_schema/PDS4_PDS_1400.xsd http://pds.nasa.gov/pds4/sp/v1 PDS4_SP_1001.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1000.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1101.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1400.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1\\thttp://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1100.xsd',
#  'http://pegasus.isi.edu/schema/DAX http://pegasus.isi.edu/schema/dax-2.1.xsd',
#  'http://pegasus.isi.edu/schema/DAX http://pegasus.isi.edu/schema/dax-3.4.xsd',
#  'http://pegasus.isi.edu/schema/sitecatalog http://pegasus.isi.edu/schema/sc-3.0.xsd',
#  'http://pegasus.isi.edu/schema/sitecatalog http://pegasus.isi.edu/schema/sc-4.0.xsd',
#  'http://phospho.elm.eu.org/webservice/schema/Instance.xsd',
#  'http://phospho.elm.eu.org/webservice/schema/Substrate.xsd',
#  'http://portal.gov.cz/portal/xsd/PvsRejstrikObsah http://portal.gov.cz/portal/xsd/PvsRejstrikObsah.xsd',
#  'http://portal.gov.cz/portal/xsd/PvsRejstrikVazby http://portal.gov.cz/portal/xsd/PvsRejstrikVazby.xsd',
#  'http://pubchem.ncbi.nlm.nih.gov.libproxy.lib.unc.edu/hierarchy_data http://pubchem.ncbi.nlm.nih.gov.libproxy.lib.unc.edu/pug_rest/hierarchy_data.xsd',
#  'http://pubchem.ncbi.nlm.nih.gov.libproxy.lib.unc.edu/pug_rest http://pubchem.ncbi.nlm.nih.gov.libproxy.lib.unc.edu/pug_rest/pug_rest.xsd',
#  'http://pubchem.ncbi.nlm.nih.gov/hierarchy_data http://pubchem.ncbi.nlm.nih.gov/pug_rest/hierarchy_data.xsd',
#  'http://pubchem.ncbi.nlm.nih.gov/pug_rest http://pubchem.ncbi.nlm.nih.gov/pug_rest/pug_rest.xsd',
#  'http://purl.org/dc/elements/1.1 http://dublincore.org/schemas/xmls/qdc/2003/04/02/dc.xsd http://purl.org/NET/ils-holdings-schema/1 http://purl.org/NET/ils-holdings-schema/1/schema',
#  'http://purl.org/dc/elements/1.1/ http://dublincore.org/schemas/xmls/qdc/2003/04/02/dc.xsd',
#  'http://purl.org/dc/elements/1.1/ http://www.language-archives.org/OLAC/1.0/dc.xsd http://purl.org/dc/terms/ http://www.language-archives.org/OLAC/1.0/dcterms.xsd http://www.language-archives.org/OLAC/1.0/ http://www.language-archives.org/OLAC/1.0/olac.xsd http://www.compuling.net/projects/olac/ http://www.language-archives.org/OLAC/1.0/third-party/software.xsd',
#  'http://purl.org/dc/elements/1.1/ http://www.language-archives.org/OLAC/1.1/dc.xsd http://purl.org/dc/terms/ http://www.language-archives.org/OLAC/1.1/dcterms.xsd http://www.language-archives.org/OLAC/1.1/ http://www.language-archives.org/OLAC/1.1/olac.xsd',
#  'http://purl.org/dc/terms/ http://dublincore.org/schemas/xmls/qdc/2003/04/02/dcterms.xsd',
#  'http://purl.org/dc/terms/ http://dublincore.org/schemas/xmls/qdc/dcterms.xsd',
#  'http://purl.org/mla/pnds/pndsdc/ http://www.ukoln.ac.uk/metadata/pns/pndsdcxml/2005-06-13/xmls/pndsdc.xsd',
#  'http://rs.gbif.org/extension/ http://rs.gbif.org/schema/extension.xsd',
#  'http://rs.tdwg.org/dwc/tdwg_dw_core.xsd',
#  'http://rs.tdwg.org/dwc/tdwg_dw_curatorial.xsd',
#  'http://rs.tdwg.org/dwc/tdwg_dw_element.xsd',
#  'http://rs.tdwg.org/dwc/tdwg_dw_geospatial.xsd',
#  'http://rs.tdwg.org/dwc/text/ http://rs.tdwg.org/dwc/text/tdwg_dwc_text.xsd',
#  'http://rs.tdwg.org/tapir/1.0 http://rs.tdwg.org/tapir/1.0/schema/tdwg_tapir.xsd',
#  'http://sabiork.h-its.org:80/sabiork?xsd=1',
#  'http://scap.nist.gov/schema/configuration/0.1 http://nvd.nist.gov/schema/configuration_0.1.xsd http://scap.nist.gov/schema/scap-core/0.3 http://nvd.nist.gov/schema/scap-core_0.3.xsd http://scap.nist.gov/schema/feed/configuration/0.1 http://nvd.nist.gov/schema/nvd-cce-feed_0.1.xsd',
#  'http://schema.datacite.org/meta/kernel-2.0/metadata.xsd',
#  'http://schema.datacite.org/meta/kernel-3.0/metadata.xsd',
#  'http://schema.datacite.org/oai/oai-1.0/ http://schema.datacite.org/oai/oai-1.0/oai.xsd',
#  'http://schema.rvdata.us/1.2 http://schema.rvdata.us/1.2/base.xsd',
#  'http://schemas.opengis.net/gml/2.1.2/feature.xsd',
#  'http://schemas.opengis.net/gml/3.1.1/base/feature.xsd',
#  'http://schemas.opengis.net/gml/3.1.1/base/gml.xsd',
#  'http://schemas.opengis.net/gml/3.1.1/profiles/gmlsfProfile/1.0.0/gmlsfLevels.xsd',
#  'http://schemas.opengis.net/gml/3.2.1/gml.xsd',
#  'http://schemas.opengis.net/iso/19139/20070417/gmd/gmd.xsd',
#  'http://schemas.opengis.net/ows/1.1.0/owsAll.xsd',
#  'http://schemas.opengis.net/ows/1.1.0/owsExceptionReport.xsd',
#  'http://schemas.opengis.net/sweCommon/2.0/swe.xsd',
#  'http://schemas.opengis.net/wms/1.3.0/capabilities_1_3_0.xsd',
#  'http://schemas.seadatanet.org/Standards-Software/Metadata-formats/iso19139/gmi/gmi.xsd',
#  'http://schemas.xmlsoap.org/encoding/ AnyConnectProfile.xsd',
#  'http://schemas.xmlsoap.org/ws/2004/08/addressing',
#  'http://scidb.evergreen.edu/databank/databaseCenter/schemas/teof.xsd',
#  'http://scout.wisc.edu/XML/searchInfo/ http://scout.wisc.edu/XML/searchInfo.xsd',
#  'http://search.ams.usda.gov/FarmersMarkets/v1/data.svc?xsd=xsd0',
#  'http://search.ams.usda.gov/FarmersMarkets/v1/data.svc?xsd=xsd1',
#  'http://search.ams.usda.gov/FarmersMarkets/v1/data.svc?xsd=xsd2',
#  'http://sedac.ciesin.columbia.edu:80/geoserver/schemas/wcs/1.1.1/wcsGetCapabilities.xsd',
# ...
#  'http://www.isotc211.org/2005/gmd http://schemas.opengis.net/csw/2.0.2/profiles/apiso/1.0.0/apiso.xsd',
#  'http://www.isotc211.org/2005/gmd http://schemas.opengis.net/iso/19139/20060504/gmd/gmd.xsd',
#  'http://www.isotc211.org/2005/gmd http://schemas.opengis.net/iso/19139/20070417/gmd/gmd.xsd',
#  'http://www.isotc211.org/2005/gmd http://standards.iso.org/ittf/PubliclyAvailableStandards/ISO_19139_Schemas/gmd/gmd.xsd',
#  'http://www.isotc211.org/2005/gmd http://www.isotc211.org/2005/gmd/gmd.xsd',
#  'http://www.isotc211.org/2005/gmd http://www.isotc211.org/2005/gmd/gmd.xsd http://www.isotc211.org/2005/srv http://schemas.opengis.net/iso/19139/20060504/srv/srv.xsd',
#  'http://www.isotc211.org/2005/gmd http://www.isotc211.org/2005/gmd/gmd.xsd http://www.isotc211.org/2005/srv http://schemas.opengis.net/iso/19139/20060504/srv/srv.xsd http://www.isotc211.org/2005/gco http://www.isotc211.org/2005/gco/gco.xsd',
#  'http://www.isotc211.org/2005/gmd http://www.isotc211.org/2005/gmd/gmd.xsd http://www.opengis.net/gml http://schemas.opengis.net/gml/3.1.1/base/gml.xsd',
#  'http://www.isotc211.org/2005/gmd http://www.isotc211.org/2005/gmd/gmd.xsd http://www.opengis.net/gml http://www.opengis.net/gml/gml.xsd',
#  'http://www.isotc211.org/2005/gmd http://www.isotc211.org/2005/gmd/metadataEntity.xsd',
#  'http://www.isotc211.org/2005/gmd http://www.isotc211.org/schemas/2005/gmd/gmd.xsd',
#  'http://www.isotc211.org/2005/gmd http://www.ngdc.noaa.gov/metadata/published/xsd/schema.xsd',
#  'http://www.isotc211.org/2005/gmd http://www.ngdc.noaa.gov/metadata/published/xsd/schema/gmd/gmd.xsd',
#  'http://www.isotc211.org/2005/gmi C:/users/miles.patrick/ISO/ISOngdc/schema/gmi/gmi.xsd',
#  'http://www.isotc211.org/2005/gmi Q:/users/mize.jacqueline/ISO/ISOngdc/schema/gmi/gmi.xsd',
#  'http://www.isotc211.org/2005/gmi ftp://ftp.ncddc.noaa.gov/pub/Metadata/Online_ISO_Training/Intro_to_ISO/schemas/ISObio/schema.xsd',
#  'http://www.isotc211.org/2005/gmi http://cdn.earthdata.nasa.gov/iso/schema/1.0/ISO19115-2_EOS.xsd',
#  'http://www.isotc211.org/2005/gmi http://ngdc.noaa.gov/metadata/published/xsd/schema.xsd',
#  'http://www.isotc211.org/2005/gmi http://www.ngdc.noaa.gov/metadata/published/xsd/schema.xsd',
#  'http://www.isotc211.org/2005/gmx ../../gmx/gmx.xsd http://www.isotc211.org/2005/gco ../../gco/gco.xsd http://www.opengis.net/gml ../../gml/gml.xsd http://www.w3.org/1999/xlink ../../xlink/xlinks.xsd',
#  'http://www.isotc211.org/2005/gmx ../../gmx/gmx.xsd http://www.isotc211.org/2005/gco ../../gco/gco.xsd http://www.opengis.net/gml/3.2 ../../../ISO_19136_Schemas/gml.xsd http://www.w3.org/1999/xlink http://schemas.opengis.net/xlink/1.0.0/xlinks.xsd',
#  'http://www.isotc211.org/2005/gmx http://eden.ign.fr/xsd/isotc211/isofull/20090316/gmx/gmx.xsd',
#  'http://www.isotc211.org/2005/gmx http://eden.ign.fr/xsd/isotc211/isofull/20090316/gmx/gmx.xsd http://www.isotc211.org/2005/srv http://eden.ign.fr/xsd/isotc211/isofull/20090316/srv/srv.xsd',
#  'http://www.isotc211.org/2005/gmx http://standards.iso.org/ittf/PubliclyAvailableStandards/ISO_19139_Schemas/gmx/gmx.xsd',
#  'http://www.isotc211.org/2005/gmx http://standards.iso.org/ittf/PubliclyAvailableStandards/ISO_19139_Schemas/gmx/gmx.xsd http://www.isotc211.org/2005/gco http://standards.iso.org/ittf/PubliclyAvailableStandards/ISO_19139_Schemas/gco/gco.xsd http://www.opengis.net/gml/3.2 http://standards.iso.org/ittf/PubliclyAvailableStandards/ISO_19136_Schemas/gml.xsd http://www.w3.org/1999/xlink http://schemas.opengis.net/xlink/1.0.0/xlinks.xsd',
#  'http://www.isotc211.org/2005/gmx http://www.isotc211.org/2005/gmx/catalogues.xsd http://www.isotc211.org/2005/gco http://www.isotc211.org/2005/gco/gco.xsd http://www.opengis.net/gml http://www.isotc211.org/2005/gml/dictionary.xsd http://www.w3.org/1999/xlink http://www.isotc211.org/2005/xlink/xlinks.xsd',
#  'http://www.isotc211.org/2005/grg http://standards.iso.org/iso/19135/-2/register.xsd',
#  'http://www.isotc211.org/2005/srv http://schemas.opengis.net/iso/19139/20060504/srv/srv.xsd',
#  'http://www.isotc211.org/schemas/2005/gco/gcoBase.xsd',
#  'http://www.isotc211.org/schemas/2005/gmd/gmd.xsd',
#  'http://www.isotc211.org/schemas/2005/gmx/gmx.xsd',
#  'http://www.ivoa.net/xml/STC/stc-v1.30.xsd http://hea-www.harvard.edu/~arots/nvometa/v1.30/stc-v1.30.xsd',
#  'http://www.ivoa.net/xml/STC/stc-v1.30.xsd http://www.ivoa.net/xml/STC/stc-v1.30.xsd',
#  'http://www.ivoa.net/xml/STC/stc-v1.30.xsd stc-v1.30.xsd',
#  'http://www.ivoa.net/xml/STC/stc-v1.30.xsd stc-v1.30.xsd http://www.ivoa.net/xml/STC/stc-v1.30.xsd stc-v1.30.xsd',
#  'http://www.ivoa.net/xml/VOResource/v0.10 http://www.ivoa.net/xml/VOResource/v0.10 http://www.ivoa.net/xml/VORegistry/v0.3 http://www.ivoa.net/xml/VORegistry/v0.3 http://www.ivoa.net/xml/SIA/v0.7 http://www.ivoa.net/xml/SIA/v0.7 http://www.ivoa.net/xml/ConeSearch/v0.3 http://www.ivoa.net/xml/ConeSearch/v0.3 http://www.ivoa.net/xml/VODataService/v0.5 http://www.ivoa.net/xml/VODataService/v0.5',
#  'http://www.ivoa.net/xml/VOTable/VOTable/v1.1',
#  'http://www.ivoa.net/xml/VOTable/v1.1',
#  'http://www.ivoa.net/xml/VOTable/v1.1 http://www.ivoa.net/xml/VOTable/v1.1',
#  'http://www.landxml.org/schema/LandXML-1.0 http://www.landxml.org/schema/LandXML-1.0.xsd',
#  'http://www.landxml.org/schema/LandXML-1.0 http://www.landxml.org/schema/LandXML-1.0/LandXML-1.0.xsd',
#  'http://www.landxml.org/schema/LandXML-1.1 http://www.landxml.org/schema/LandXML-1.1/LandXML-1.1.xsd',
#  'http://www.language-archives.org/OLAC/1.0/ http://www.language-archives.org/OLAC/1.0/olac.xsd http://purl.org/dc/elements/1.1/ http://www.language-archives.org/OLAC/1.0/dc.xsd http://purl.org/dc/terms/ http://www.language-archives.org/OLAC/1.0/dcterms.xsd',
#  'http://www.language-archives.org/OLAC/1.1/ http://www.language-archives.org/OLAC/1.1/olac.xsd',
#  'http://www.language-archives.org/OLAC/1.1/olac-archive http://www.language-archives.org/OLAC/1.1/olac-archive.xsd',
#  'http://www.legislation.gov.uk/namespaces/legislation http://www.legislation.gov.uk/schema/legislation.xsd',
#  'http://www.loc.gov/MARC21/slim http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd',
#  'http://www.loc.gov/METS/ ../../schema/mets.xsd http://www.w3.org/TR/xlink ../../schema/xlink.xsd http://www.loc.gov/mods/v3 ../../schema/mods-3-0.xsd http://odl.ox.ac.uk/odl-mods-extensions/1.0/ ../../schema/odl.xsd',
#  'http://www.loc.gov/METS/ http://ahds.ac.uk/srvc-oai/xsd/mets.xsd http://ahds.ac.uk/ns/cmf/2.0/ http://ahds.ac.uk/srvc-oai/xsd/cmf2.xsd',
#  'http://www.loc.gov/METS/ http://www.loc.gov./standards/mets/mets.xsd http://purl.org/dc/elements/1.1/ http://dublincore.org/schemas/xmls/qdc/2003/04/02/dc.xsd http://www.loc.gov/standards/premis http://www.loc.gov/standards/premis/PREMIS-v1-0.xsd',
#  'http://www.loc.gov/METS/ http://www.loc.gov/mets/mets.xsd\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\thttp://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-0.xsd',
#  'http://www.loc.gov/METS/ http://www.loc.gov/mets/mets.xsd\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\thttp://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-0.xsd http://www.loc.gov/mix/ http://www.loc.gov/mix/mix.xsd',
#  'http://www.loc.gov/METS/ http://www.loc.gov/mets/mets.xsdhttp://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-0.xsd',
#  'http://www.loc.gov/METS/ http://www.loc.gov/standards/mets/mets.xsd',
#  'http://www.loc.gov/METS/ http://www.loc.gov/standards/mets/mets.xsd http://www.loc.gov/mix/v20 http://www.loc.gov/standards/mix/mix20/mix20.xsd http://www.loc.gov/AMD/ http://lcweb2.loc.gov/mets/Schemas/AMD.xsd http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-2.xsd http://www.loc.gov/VMD/ http://lcweb2.loc.gov/mets/Schemas/VMD.xsd',
#  'http://www.loc.gov/METS/ http://www.loc.gov/standards/mets/mets.xsd http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/mods.xsd http://cosimo.stanford.edu/sdr/metsrights/ http://www.loc.gov/standards/rights/METSRights.xsd http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd info:lc/xmlns/premis-v2 http://www.loc.gov/standards/premis/v2/premis.xsd http://purl.org/dc/elements/1.1/ http://dublincore.org/schemas/xmls/qdc/2008/02/11/dc.xsd http://purl.org/dc/terms/ http://dublincore.org/schemas/xmls/qdc/2008/02/11/dcterms.xsd',
#  'http://www.loc.gov/METS/ http://www.loc.gov/standards/mets/mets.xsd http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/mods.xsd http://www.loc.gov/standards/premis/v1 http://www.loc.gov/standards/premis/v1/Event-v1-1.xsd http://www.w3.org/1999/xlink http://www.loc.gov/standards/mods/xlink.xsd http://www.loc.gov/audioMD/ http://www.loc.gov/standards/amdvmd/audioMD.xsd',
#  'http://www.loc.gov/METS/ http://www.loc.gov/standards/mets/mets.xsd http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-0.xsd',
#  'http://www.loc.gov/METS/ http://www.loc.gov/standards/mets/mets.xsd http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-2.xsd http://www.loc.gov/mix/ http://www.loc.gov/standards/mix/mix02.xsd http://www.w3.org/1999/xlink http://www.loc.gov/standards/mets/xlink.xsd http://www.loc.gov/standards/premis/v1 http://www.loc.gov/standards/premis/v1/PREMIS-v1-1.xsd',
#  'http://www.loc.gov/METS/ http://www.loc.gov/standards/mets/mets.xsd http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-2.xsd http://www.loc.gov/standards/premis/v1 http://www.loc.gov/standards/premis/v1/Event-v1-1.xsd http://www.w3.org/1999/xlink http://www.loc.gov/standards/mods/xlink.xsd http://www.lib.utexas.edu/schema/UTVIDEOTech.xsd http://www.lib.utexas.edu/schema/UTVIDEOSrc.xsd',
#  'http://www.loc.gov/METS/ http://www.loc.gov/standards/mets/mets.xsd http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-3.xsd',
#  'http://www.loc.gov/METS/ http://www.loc.gov/standards/mets/mets.xsd http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd',
#  'http://www.loc.gov/METS_Profile/ \\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t http://www.loc.gov/standards/mets/profile_docs/mets.profile.v1-2.xsd\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t http://www.loc.gov/METS/\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t http://www.loc.gov/standards/mets/mets.xsd\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t http://www.loc.gov/mods/v3\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t http://www.loc.gov/standards/mods/v3/mods-3-0.xsd',
#  'http://www.loc.gov/METS_Profile/ http://www.loc.gov/standards/mets/profile_docs/mets.profile.v1-2.xsd http://www.loc.gov/METS/ http://www.loc.gov/standards/mets/version16/mets.v1-6.xsd',
#  'http://www.loc.gov/METS_Profile/\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t http://www.loc.gov/standards/mets/profile_docs/mets.profile.v1-2.xsd\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t http://www.loc.gov/METS/\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t http://www.loc.gov/standards/mets/mets.xsd\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t http://www.loc.gov/mods/v3\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t http://www.loc.gov/standards/mods/v3/mods-3-0.xsd',
#  'http://www.loc.gov/METS_Profile/http://www.loc.gov/standards/mets/profile_docs/mets.profile.v1-2.xsd http://www.loc.gov/METS/ http://www.loc.gov/standards/mets/mets.xsd http://www.loc.gov/mods/ http://www.loc.gov/standards/mods/v3/mods-3-0.xsd',
#  'http://www.loc.gov/METS_Profile/v2 http://www.loc.gov/standards/mets/profile_docs/mets.profile.v2-0.xsd',
#  'http://www.loc.gov/METS_Profile/v2 http://www.loc.gov/standards/mets/profile_docs/mets.profile.v2-0.xsd http://www.loc.gov/METS/ http://www.loc.gov/standards/mets/mets.xsd http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/mods.xsd http://cosimo.stanford.edu/sdr/metsrights/ http://www.loc.gov/standards/rights/METSRights.xsd http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd info:lc/xmlns/premis-v2 http://www.loc.gov/standards/premis/v2/premis.xsd http://purl.org/dc/elements/1.1/ http://dublincore.org/schemas/xmls/qdc/2008/02/11/dc.xsd http://purl.org/dc/terms/ http://dublincore.org/schemas/xmls/qdc/2008/02/11/dcterms.xsd',
#  'http://www.loc.gov/mads/mads.xsd',
#  'http://www.loc.gov/mix/ http://www.loc.gov/mix/mix02.xsd',
#  'http://www.loc.gov/mix/v20 http://www.loc.gov/standards/mix/mix20/mix20.xsd',
#  'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-0.xsd',
#  'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-1.xsd',
#  'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-2.xsd',
#  'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-3.xsd',
#  'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-3.xsd http://www.dlib.indiana.edu/metadata/inharmony/extensionElements http://www.dlib.indiana.edu/metadata/inharmony/extensionElements/inHarmonyExtensionElements.xsd',
#  'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-3.xsd http://www.loc.gov/METS/ http://www.loc.gov/standards/mets/version17/mets.v1-7.xsd http://www.loc.gov/standards/premis/ http://www.loc.gov/standards/premis/v2/premis-v2-0.xsd http://www.loc.gov/standards/mix/ http://www.loc.gov/standards/mix/mix.xsd',
#  'http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-4.xsd',
#  'http://www.loc.gov/standards/mets/xlink.xsd',
#  'http://www.loc.gov/standards/xlink/xlink.xsd',
#  'http://www.loc.gov/zing/srw/ http://www.loc.gov/standards/sru/sru1-1archive/xml-files/srw-types.xsd',
#  'http://www.mediawiki.org/xml/export-0.9/ http://www.mediawiki.org/xml/export-0.9.xsd',
#  'http://www.metadatatechnology.com/beta/SDMX2.1/SDMXCommon.xsd',
#  'http://www.metadatatechnology.com/beta/SDMX2.1/SDMXDataStructureSpecific.xsd',
#  'http://www.metaforclimate.eu/cim/0.2 file:/home/alias/metafor/svc-10mar09/software.xsd',
#  'http://www.metaforclimate.eu/cim/1.4 Z:\\\\CIM\\\\XSDs\\\\dev0p3\\\\activity.xsd',
#  'http://www.mpi.nl/IMDI/Schema/IMDI ./IMDI.xsd',
#  'http://www.mpi.nl/tools/elan/EAFv2.6.xsd',
#  'http://www.mpi.nl/tools/elan/EAFv2.7.xsd',
#  'http://www.mpi.nl/tools/elan/Prefs_v1.1.xsd',
#  'http://www.ncbi.nlm.nih.gov ftp://ftp.ncbi.nlm.nih.gov/pubchem/specifications/pubchem.xsd',
#  'http://www.ncbi.nlm.nih.gov.libproxy.lib.unc.edu ftp://ftp.ncbi.nlm.nih.gov/pubchem/specifications/pubchem.xsd',
#  'http://www.ncbi.nlm.nih.gov/viewvc/v1/trunk/sra/doc/SRA_1-5/SRA.analysis.xsd?view=co',
#  'http://www.ncbi.nlm.nih.gov/viewvc/v1/trunk/sra/doc/SRA_1-5/SRA.experiment.xsd?view=co',
#  'http://www.ncbi.nlm.nih.gov/viewvc/v1/trunk/sra/doc/SRA_1-5/SRA.run.xsd?view=co',
#  'http://www.nereus4economics.info/ http://drcwww.uvt.nl/~place/nereus/nereusx.xsd',
#  'http://www.ngdc.noaa.gov/metadata/published/xsd/ngdcSchema/schema.xsd',
#  'http://www.ngdc.noaa.gov/metadata/published/xsd/schema.xsd',
#  'http://www.ngdc.noaa.gov/metadata/published/xsd/schema/gmi http://www.ngdc.noaa.gov/metadata/published/xsd/schema.xsd',
#  'http://www.ngdc.noaa.gov/mgg/ecs/metadata/seismic/xml/seismicMetadata.xsd',
#  'http://www.niso.org/2008/ncip http://www.niso.org/schemas/ncip/v2_01/ncip_v2_01.xsd',
#  'http://www.nws.noaa.gov/forecasts/xml/DWMLgen/schema/DWML.xsd',
#  'http://www.oasis-open.org/committees/download.php/11026/sstc-saml-schema-protocol-2.0.xsd',
#  'http://www.oasis-open.org/committees/download.php/11027/sstc-saml-schema-assertion-2.0.xsd',
#  'http://www.oasis-open.org/committees/download.php/915/cs-xacml-schema-policy-01.xsd',
#  'http://www.oasis-open.org/committees/download.php/919/cs-xacml-schema-context-01.xsd',
#  'http://www.ogcnetwork.net/schemas/wps/1.0.0/wpsDescribeProcess.xsd',
#  ...]

# %% [markdown]
# **1,960 unique references.**

# %%
# the references split by whitespace
with open('outputs/unique_schemas_sorted.txt', 'r') as f:
    unique_schemas = [s.strip() for s in f.readlines() if s]

unique_schemas
# Out:
# ['../../../ISO_19136_Schemas/gml.xsd',
#  '../../../OGC/gml/3.2.1/gml.xsd',
#  '../../../OGC/iso/19139/20070417/gmd/gmd.xsd',
#  '../../../OGC/om/1.0.1/om.xsd',
#  '../../../OGC/sweCommon/1.0.2/swe.xsd',
#  '../../../general-component-schema.xsd',
#  '../../appinfo/2.0/appinfo.xsd',
#  '../../common/1.0/common.xsd',
#  '../../dei/2012/dei-2012-01-31.xsd',
#  '../../gco/gco.xsd',
#  '../../general-component-schema.xsd',
#  '../../gml/3.1.1/base/gml.xsd',
#  '../../gml/gml.xsd',
#  '../../gmx/gmx.xsd',
#  '../../schema/mets.xsd',
#  '../../schema/mods-3-0.xsd',
#  '../../schema/odl.xsd',
#  '../../schema/xlink.xsd',
#  '../../structures/2.0/structures.xsd',
#  '../../xlink/1.0.0/xlinks.xsd',
#  '../../xlink/xlinks.xsd',
#  '../AOML/AEML.xsd',
#  '../AOML/AOML.xsd',
#  '../common/UBL-CommonBasicComponents-2.0.xsd',
#  '../common/UBL-CommonExtensionComponents-2.0.xsd',
#  '../common/ws_common_1_0b.xsd',
#  '../fgdc-std-001-1998/fgdc-std-001-1998-ann.xsd',
#  '../gco/gco.xsd',
#  '../general-component-schema.xsd',
#  '../gmd/gmd.xsd',
#  '../itsoutput.xsd',
#  '../napm/napmCharacterString.xsd',
#  '../schema/exchange/FoiaAnnualReport.xsd',
#  '../schema/frame.xsd',
#  '../schemas/ioosObservationSpecializations.xsd',
#  '../schemas/iso19139fra/gmd/gmd.xsd',
#  '..\\\\wpsGetCapabilities.xsd',
#  './IMDI.xsd',
#  './aggregateTypes.xsd',
#  './basicTypes.xsd',
#  './encoding.xsd',
#  './simpleTypes.xsd',
#  './types.xsd',
#  '/data',
#  '/finance/disclosure/schema/AdminFine.xsd',
#  '/finance/disclosure/schema/Leadership.xsd',
#  '/finance/disclosure/schema/LobbyistBundle.xsd',
#  '/schema/folder.xsd',
#  '/schemas/INF_AlmanacData_V01.02.xsd',
#  '0/WQX_WQX_v2.0.xsd',
#  '101.xsd',
#  '102.xsd',
#  '103.xsd',
#  '104.xsd',
#  '105.xsd',
#  '11.xsd',
#  '12.xsd',
#  '17.xsd',
#  '18.xsd',
#  '19.xsd',
#  '192.xsd',
#  '19a.xsd',
#  '25.xsd',
#  '26.xsd',
#  '27.xsd',
#  '33.xsd',
#  '33a.xsd',
#  '38.xsd',
#  '41.xsd',
#  '43.xsd',
#  '45.xsd',
#  '45a.xsd',
#  '46.xsd',
#  '?version=1.3.0&service=WMS&request=GetSchemaExtension',
#  'ADWR20140815.xsd',
#  'AccessControlServiceMessages.xsd',
#  'AdjacencyTable.xsd',
#  'AdministrationServiceMessages.xsd',
#  'AnyConnectProfile.xsd',
#  'AppSchemaDataAccess.xsd',
#  'AuthenticationServiceMessages.xsd',
#  'BasicTypes.xsd',
#  'BooleanControls.xsd',
#  'Bus_Linie',
#  'C:/users/miles.patrick/ISO/ISOngdc/schema/gmi/gmi.xsd',
#  'CFStandardNameTable-1.1.xsd',
#  'CalendarServiceMessages.xsd',
#  'CatalogServiceMessages.xsd',
#  'Charts.xsd',
#  'Comments.xsd',
#  'CommonTypes.xsd',
#  'CoreVocabularyAggregateComponents-v1.00.xsd',
#  'CoreVocabularyBasicComponents-v1.00.xsd',
#  'D:\\\\XML\\\\Hydroml.xsd',
#  'DD8723-5-DCTerms.xsd',
#  'DR_sections.xsd',
#  'Decisions.xsdDigital_Enterprise.xsd',
#  'Discussions.xsd',
#  'EDXL-RMCommonTypes.xsd',
#  'EchoExceptions.xsd',
#  'Equipment.xsd',
#  'EventNotificationServiceMessages.xsd',
#  'EventSinkMessages.xsd',
#  'ExtendedServicesServiceMessages.xsd',
#  'Fahrweg_Graph_GK31_5.xsd',
#  'Fahrweg_Graph_WGS84.xsd',
#  'Fahrweg_Linie_GK31_5.xsd',
#  'Fahrweg_Linie_WGS84.xsd',
#  'ForzaLavoroLiguria.xsd',
#  'GranuleProvenance.xsd',
#  'Group2ManagementServiceMessages.xsd',
#  'HVCRMethods.xsd',
#  'HeliocentricTrajectoriesService_schema1.xsd',
#  'HorizontalControl.xsd',
#  'HydroXC.xsd',
#  'INSPIRE',
#  'Junctions.xsd',
#  'Metadata.xsd',
#  'MetadataCommon.xsd',
#  'N2.xsd',
#  'N3.xsd',
#  'N4.xsd',
#  'NF2_register_system.xsd',
#  'OccupatiLiguria.xsd',
#  'OrderFulfillmentFaults.xsd',
#  'OrderFulfillmentMessages.xsd',
#  'OrderFulfillmentTypes.xsd',
#  'OrderManagementServiceMessages.xsd',
#  'OrderProcessingServiceMessages.xsd',
#  'PDS4_SP_1001.xsd',
#  'PI_Tasks.xsd',
#  'PKTDSegurConfiguration.xsd',
#  'PKTDSegurDynn.xsd',
#  'ProviderServiceMessages.xsd',
#  'Q:/users/mize.jacqueline/ISO/ISOngdc/schema/gmi/gmi.xsd',
#  'Q:/users/mize.jacqueline/ISO/gfc/gfc.xsd',
#  'Roster.xsd',
#  'SDMXGenericMetadata.xsd',
#  'SDMXMessage.xsd',
#  'SchedulingPeriod-3.0.xsd',
#  'SensitivityAnalysisService?xsd=xsd0.xsd',
#  'ServiceManagementServiceMessages.xsd',
#  'StatBez_Linz.xsd',
#  'StatBez_Linz_EPSG_31255.xsd',
#  'SteadyStateService?xsd=xsd0.xsd',
#  'StyledLayerDescriptor.xsd',
#  'SubscriptionServiceMessages.xsd',
#  'SurveyStatistics.xsd',
#  'TaxonomyServiceMessages.xsd',
#  'TimeCourseService?xsd=xsd0.xsd',
#  'TypeLibrary-array.xsd',
#  'TypeLibrary-list.xsd',
#  'TypeLibrary-math.xsd',
#  'TypeLibrary-quantity.xsd',
#  'TypeLibrary-text.xsd',
#  'Uncertainty.xsd',
#  'UserServiceMessages.xsd',
#  'VerticalControl.xsd',
#  'WHU-LIESMARS-WPS?xsd=ws.xsd',
#  'Z:\\\\CIM\\\\XSDs\\\\dev0p3\\\\activity.xsd',
#  'area-type-table-1.1.xsd',
#  'cgiUtilities.xsd',
#  'civil-wedding-and-civil-partnership-venue-approvals.xsd',
#  'classes.xsd',
#  'cmdi-virtual-collection.xsd',
#  'comments.xsd',
#  'counter4_0.xsd',
#  'counter4_1.xsd',
#  'counterElements3_0.xsd',
#  'counterElements4_0.xsd',
#  'counterElements4_1.xsd',
#  'currency-ent-all-draft-2014-01-31.xsd',
#  'datatypes.xsd',
#  'dc.xsd',
#  'dcterms.xsd',
#  'ddi:codebook:2_5',
#  'ddi:instance:3_0',
#  'ddi:instance:3_2',
#  'dei-ent-all-draft-2014-01-31.xsd',
#  'dkcoin.xsd',
#  'eap-metadata.xsd',
#  'earthMaterial.xsd',
#  'earthresourceml.xsd',
#  'efetch.xsd',
#  'efetch_db_gene.xsd',
#  'efetch_db_nlmc.xsd',
#  'efetch_db_omim.xsd',
#  'efetch_db_pmc.xsd',
#  'efetch_db_seq.xsd',
#  'efetch_db_snp.xsd',
#  'efetch_db_taxon.xsd',
#  'egquery.xsd',
#  'einfo.xsd',
#  'elink.xsd',
#  'eml.xsd',
#  'eml://ecoinformatics.org/eml-2.0.0',
#  'eml://ecoinformatics.org/eml-2.0.1',
#  'eml://ecoinformatics.org/eml-2.1.0',
#  'eml://ecoinformatics.org/eml-2.1.1',
#  'eml://ecoinformatics.org/lter-project-2.1.0',
#  'erxl.xsd',
#  'esearch.xsd',
#  'espell.xsd',
#  'espiDerived.xsd',
#  'esummary.xsd',
#  'eurofxref.xsd',
#  'file:///C:\\\\Workplan\\\\Thesaurus%20interchange%20standard\\\\iso25964-5-flat.xsd',
#  'file:///D:/schemas/ISOngdc/schema/gmd/citation.xsd',
#  'file:///E:/SW/moon/im/fgdc-std-001-1998-ann.xsd',
#  'file:/C:/Schemas/DDI_3_2_2013_11_13/schema/instance.xsd',
#  'file:/Q:/itsd/Digital.Bodleian/schema/generated_dc.xsd',
#  'file:/home/alias/metafor/svc-10mar09/software.xsd',
#  'file:/home/dietuyt/svn/clarin/metadata/trunk/toolkit/general-component-schema.xsd',
#  'ftp://ftp.ncbi.nlm.nih.gov/pubchem/specifications/pubchem.xsd',
#  'ftp://ftp.ncddc.noaa.gov/pub/Metadata/Online_ISO_Training/Intro_to_ISO/schemas/ISObio/schema.xsd',
#  'ftp://ftp.sra.ebi.ac.uk/meta/xsd/sra_1_3/SRA.run.xsd',
#  'ftp://ftp.sra.ebi.ac.uk/meta/xsd/sra_1_5/SRA.experiment.xsd',
#  'ftp://ftp.sra.ebi.ac.uk/meta/xsd/sra_1_5/SRA.run.xsd',
#  'ftp://ftp.sra.ebi.ac.uk/meta/xsd/sra_1_5/SRA.sample.xsd',
#  'ftp://ftp.sra.ebi.ac.uk/meta/xsd/sra_1_5/SRA.study.xsd',
#  'ftp://ftp.sra.ebi.ac.uk/meta/xsd/sra_1_5/SRA.submission.xsd',
#  'gambling-permits.xsd',
#  'gambling-premises-licences.xsd',
#  'geo-oasis.xsd',
#  'geosciml-core.xsd',
#  'ghodata.xsd',
#  'gml-ish.xsd',
#  'gutenprint.xsd',
#  'http:///jpa2/javax/persistence.ecore',
#  'http://107.20.228.18/arcgis/services/Wetlands/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://127.0.0.1:8080/helloservice/HelloService/__container$publishing$subctx/WEB-INF/wsdl/HelloService_schema1.xsd',
#  'http://216.38.80.5/arcgis/services/AtStormViewer/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://216.38.80.5/arcgis/services/EpStormViewer/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://216.38.80.5/arcgis/services/SPC_Outlooks/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://216.38.80.5/arcgis/services/ahps_gauges/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://216.38.80.5/arcgis/services/atStorms/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://216.38.80.5/arcgis/services/cpc_weather_hazards/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://216.38.80.5/arcgis/services/epStorms/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://216.38.80.5/arcgis/services/watchwarn/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://216.38.80.5/arcgis/services/wxmap/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://adn.dlese.org',
#  'http://ads.ahds.ac.uk/XMLschema/',
#  'http://ads.ahds.ac.uk/XMLschema/ads_dc.xsd',
#  'http://ahds.ac.uk/ns/cmf/2.0/',
#  'http://ahds.ac.uk/srvc-oai/xsd/cmf2.xsd',
#  'http://ahds.ac.uk/srvc-oai/xsd/mets.xsd',
#  'http://air-climate.eionet.europa.eu/schemas/AirQualityQuestionnaire/AirQualityQuestionnaire-form4.xsd',
#  'http://alcme.oclc.org/oaicat/toolkit.xsd',
#  'http://ands.org.au/standards/rif-cs/registryObjects',
#  'http://aneto.oco/cgi-bin/worldwfs?SERVICE=WFS&VERSION=1.0.0&REQUEST=DescribeFeatureType&TYPENAME=line&OUTPUTFORMAT=XMLSCHEMA',
#  'http://aneto.oco/cgi-bin/worldwfs?SERVICE=WFS&VERSION=1.0.0&REQUEST=DescribeFeatureType&TYPENAME=multipoint&OUTPUTFORMAT=XMLSCHEMA',
#  'http://aneto.oco/cgi-bin/worldwfs?SERVICE=WFS&VERSION=1.0.0&REQUEST=DescribeFeatureType&TYPENAME=multipolygon&OUTPUTFORMAT=XMLSCHEMA',
#  'http://aneto.oco/cgi-bin/worldwfs?SERVICE=WFS&VERSION=1.0.0&REQUEST=DescribeFeatureType&TYPENAME=polygon&OUTPUTFORMAT=XMLSCHEMA',
#  'http://anss-sis.scsn.org/xml/ext-stationxml/2.0',
#  'http://anss-sis.scsn.org/xml/ext-stationxml/2.0/sis_extension.xsd',
#  'http://api.bioinfo.no/schema/BlastOutput.xsd',
#  'http://api.bioinfo.no/schema/BlastParameters.xsd',
#  'http://api.bioinfo.no/schema/ELM.xsd',
#  'http://api.bioinfo.no/schema/ELMInstancePrediction.xsd',
#  'http://api.bioinfo.no/schema/Jaspar_matrix_0.2.xsd',
#  'http://api.bioinfo.no/schema/ServiceDocumentation.xsd',
#  'http://api.echo.nasa.gov/echo/wsdl/EchoForms.xsd',
#  'http://apps.fs.fed.us/arcx/services/EDW/EDW_ALPStatusAndEncumbrance_01/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/EDW/EDW_AerialFireRetardantAvoidanceAreas_01/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/EDW/EDW_AerialFireRetardantHydrographicAvoidanceAreas_01/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/EDW/EDW_BasicOwnership_02/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/EDW/EDW_CongressionalDistricts_01/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/EDW/EDW_MVUM_01/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/EDW/EDW_PeriodicalCicadaBroods_01/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/EDW/EDW_PriorityWatersheds_01/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/EDW/EDW_RangerDistricts_03/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/EDW/EDW_RecreationOpportunities_01/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/EDW/EDW_RoadBasic_01/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/EDW/EDW_StewardshipContracting_01/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/EDW/EDW_WildernessStatus_02/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/EDW/EDW_Wilderness_02/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/r02/r02_VegetationTreatments_01/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/r02/r02_WyomingActivities_01/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/r03/r03_4FRIVegetationRxFireTreatmentsFEIS_04/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/wo_nfs_gstc/GSTC_IVMRoadsAndTrails_03/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/wo_nfs_gstc/GSTC_TARoadsAndTrailsPrint_01/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/wo_nfs_gstc/GSTC_TARoadsAndTrails_02/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/wo_nrm_iweb/NRIS_NVUMStates_01/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.fed.us/arcx/services/wo_nrm_iweb/NRM_WCATTWatershedCondAssess2011_01/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.usda.gov/arcx/services/EDW/EDW_CongressionalDistricts_04/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.fs.usda.gov/arcx/services/wo_nfs_gstc/GSTC_IVMRoadsAndTrails_01/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://apps.who.int/gho/athena/data/GHO/CM_01,CM_02,CM_03,DEVICES09,DEVICES22,HIV_0000000020,MALARIA001,MDG_0000000001,MDG_0000000003,MDG_0000000005,MDG_0000000005_AGE1519,MDG_0000000006,MDG_0000000006_AGE1519,MDG_0000000007,MDG_0000000010,MDG_0000000011,MDG_0000000013,MDG_0000000014,MDG_0000000017,MDG_0000000020,MDG_0000000023,MDG_0000000025,MDG_0000000025_AGE1519,MDG_0000000026,MDG_0000000029,MDG_0000000031,MDG_0000000033,MDG_0000000034,MH_17,MH_18,MH_6,SA_0000001688,TB_1,TB_tot_newrel,TOBACCO_0000000192,WHOSIS_000001,WHOSIS_000003,WHOSIS_000005,WHOSIS_000011,WHOSIS_000015,WHS10_1,WHS10_8,WHS10_9,WHS2_138,WHS2_162,WHS2_163,WHS2_164,WHS2_165,WHS2_166,WHS2_167,WHS2_168,WHS2_170,WHS2_171,WHS2_172,WHS2_173,WHS2_174,WHS2_3070_all,WHS2_3070_cancer,WHS2_3070_cdd,WHS2_3070_chronic,WHS2_513,WHS2_514,WHS2_515,WHS2_516,WHS2_523,WHS3_40,WHS3_41,WHS3_42,WHS3_43,WHS3_45,WHS3_46,WHS3_47,WHS3_48,WHS3_49,WHS3_50,WHS3_51,WHS3_52,WHS3_53,WHS3_55,WHS3_56,WHS3_57,WHS3_62,WHS4_100,WHS4_106,WHS4_107,WHS4_108,WHS4_111,WHS4_111_AGE1519,WHS4_115,WHS4_117,WHS4_124,WHS4_128,WHS4_129,WHS4_154,WHS4_2530,WHS6_101,WHS6_102,WHS6_116,WHS6_123,WHS6_125,WHS6_127,WHS6_136,WHS6_140,WHS6_144,WHS6_148,WHS6_150,WHS6_517,WHS6_518,WHS6_519,WHS6_520,WHS7_103,WHS7_104,WHS7_105,WHS7_108,WHS7_113,WHS7_120,WHS7_134,WHS7_139,WHS7_143,WHS7_147,WHS7_149,WHS7_156,WHS8_110,WHS9_85,WHS9_86,WHS9_88,WHS9_89,WHS9_90,WHS9_91,WHS9_92,WHS9_93,WHS9_95,WHS9_96,WHS9_97,WHS9_CBR,WHS9_CDR,WHS9_CS.xsd?format=xml&profile=simple-schema',
#  'http://apps.who.int/gho/athena/data/GHO/HIV_0000000001.xsd?format=xml&profile=simple-schema',
#  'http://apps.who.int/gho/athena/data/GHO/MORT_100.xsd?format=xml&profile=simple-schema',
#  'http://apps.who.int/gho/athena/xmart/EBOLA_MEASURE/CASES.xsd?format=xml&profile=simple-schema',
#  'http://arno.uvt.nl/xsd/1.2/arno.xsd',
#  'http://arno.uvt.nl/xsd/1.2/arno/',
#  'http://atlas.resources.ca.gov/arcgis/services/Boundaries/CPAD_AgencyLevel/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://atlas.wvgs.wvnet.edu/arcgis/services/Geology/WVGravityData/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://atlas.wvgs.wvnet.edu/arcgis/services/Geothermal/WVGeothermal_AeromagneticData/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://atlas.wvgs.wvnet.edu/arcgis/services/Geothermal/WVGeothermal_BoundariesGeography/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://atlas.wvgs.wvnet.edu/arcgis/services/Geothermal/WVGeothermal_DevonianStructureData/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://atlas.wvgs.wvnet.edu/arcgis/services/Geothermal/WVGeothermal_EarthquakeEpicenters/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://atlas.wvgs.wvnet.edu/arcgis/services/Geothermal/WVGeothermal_Infrastructure/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://atlas.wvgs.wvnet.edu/arcgis/services/Geothermal/WVGeothermal_OrdovicianStructureData/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://atlas.wvgs.wvnet.edu/arcgis/services/Geothermal/WVGeothermal_PrecambrianStructureData/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://atlas.wvgs.wvnet.edu/arcgis/services/Geothermal/WVGeothermal_TemperatureDepthData/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://atmos.nmsu.edu/pub/PDS4/schema/PHXMD_1000.xsd',
#  'http://aviationweather.gov/adds/schema/aircraftreport1_0.xsd',
#  'http://aviationweather.gov/adds/schema/airsigmet1_1.xsd',
#  'http://aviationweather.gov/adds/schema/gairmet1_0.xsd',
#  'http://aviationweather.gov/adds/schema/metar1_2.xsd',
#  'http://aviationweather.gov/adds/schema/pirep1_2.xsd',
#  'http://aviationweather.gov/adds/schema/taf1_2.xsd',
#  'http://basemap.nationalmap.gov/arcgis/services/TNM_Vector_Fills_Small/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://basemap.nationalmap.gov/arcgis/services/USGSHydroNHD/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://basemap.nationalmap.gov/arcgis/services/USGSImageryOnly/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://basemap.nationalmap.gov/arcgis/services/USGSImageryTopo/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://basemap.nationalmap.gov/arcgis/services/USGSShadedReliefOnly/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://bio.discomap.eea.europa.eu/arcgis/services/Bio/EcoTones_Dyna_LAEA/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://bio.discomap.eea.europa.eu/arcgis/services/Bio/Natura2000Hatch_Dyna_LAEA/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://bio.discomap.eea.europa.eu/arcgis/services/Bio/Natura2000Hatch_WM_joined/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://bio.discomap.eea.europa.eu/arcgis/services/Bio/Natura2000_Dyna_WGS84/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://bio.discomap.eea.europa.eu/arcgis/services/Bio/Natura2000_Dyna_WM/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://biodiversity.eionet.europa.eu/schemas/bernconvention/derogations.xsd',
#  'http://bioputer.mimuw.edu.pl:8080/tav4sb/services?xsd=add.xsd',
#  'http://bioputer.mimuw.edu.pl:8080/tav4sb/services?xsd=mathematica.xsd',
#  'http://bioputer.mimuw.edu.pl:8080/tav4sb/services?xsd=odesolver.xsd',
#  'http://bioputer.mimuw.edu.pl:8080/tav4sb/services?xsd=prism.xsd',
#  'http://bioware.ucd.ie:8080/soaplab2/typed/services/custom.slimfinder?xsd=1',
#  'http://bioware.ucd.ie:8080/soaplab2/typed/services/custom.slimfinder?xsd=3',
#  'http://bison.ijs.si/WebServices/TextNet.svc?xsd=xsd0',
#  'http://bison.ijs.si/WebServices/TextNet.svc?xsd=xsd1',
#  'http://bison.ijs.si/WebServices/TextNet.svc?xsd=xsd2',
#  'http://bison.ijs.si/WebServices/TextNet.svc?xsd=xsd3',
#  'http://bison.ijs.si/WebServices/TextNet.svc?xsd=xsd4',
#  'http://bison.ijs.si/WebServices/TextNet.svc?xsd=xsd5',
#  'http://bpmn.sourceforge.net/schemas/BPMN20.xsd',
#  'http://brg.ldeo.columbia.edu/services/LogFile.xsd',
#  'http://brg.ldeo.columbia.edu/services/LogHole.xsd',
#  'http://brg.ldeo.columbia.edu/services/wfs?SERVICE=WFS&VERSION=1.0.0&REQUEST=DescribeFeatureType&TYPENAME=LogFile&OUTPUTFORMAT=XMLSCHEMA',
#  'http://brg.ldeo.columbia.edu/services/wfs?SERVICE=WFS&VERSION=1.0.0&REQUEST=DescribeFeatureType&TYPENAME=LogHole&OUTPUTFORMAT=XMLSCHEMA',
#  'http://capec.mitre.org/data/xsd/attack_taxonomy_schema_v1.1.1.xsd',
#  'http://carocoops.org/obskml/1.0.0/obs_types.xsd',
#  'http://carocoops.org/obskml/1.0.0/uom_types.xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1271859438162/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1271859438164/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1271859438204/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1272022528363/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1284723009187/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1288172614026/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1290431694484/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1290431694581/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1320657629644/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1345561703620/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1349361150622/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1355150532312/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1360230992145/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1360931019836/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1361876010548/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1361876010571/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1361876010597/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1380106710823/xsd',
#  'http://catalog.clarin.eu/ds/ComponentRegistry/rest/registry/profiles/clarin.eu:cr1:p_1380106710826/xsd',
#  'http://cdn.earthdata.nasa.gov/iso/schema/1.0/ISO19115-2_EOS.xsd',
#  'http://chipster.csc.fi:80/chipster-ws/chipster?xsd=1',
#  'http://clear3.uconn.edu/arcgis/services/NEMO/ImperviousCover2012/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://cml.sourceforge.net/schema/cmlreact.xsd',
#  'http://coast.noaa.gov/arcgis/services/CCAP/All_Change_9606/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/CCAP/Development_9606/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/CCAP/Forest_Fragmentation_0511/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/CCAP/Wetland_0110/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/CCAP/Wetland_0511/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/CCAP/Wetland_9601/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/CCAP/conus_10/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/FloodExposureMapper/AtlanticGulfCoastalCounties/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/FloodExposureMapper/CFEM_CensusBlkGrp_PopulationDensity/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/FloodExposureMapper/CFEM_CensusBlkGrp_Poverty/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/FloodExposureMapper/CFEM_CoastalFloodHazardComposite/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/FloodExposureMapper/CFEM_CriticalFacilities/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/FloodExposureMapper/CFEM_EPA_FRSPoints/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/FloodExposureMapper/CFEM_FEMAFloodZones/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/FloodExposureMapper/CFEM_LandCover_19962010Change/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/FloodExposureMapper/CFEM_NaturalAreasOpenSpace/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/Hurricanes/AllStorms_Symbolized/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/MarineCadastre/2011PassengerVesselDensity/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/MarineCadastre/CommercialVesselDensityOctober2009_2010/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/MarineCadastre/DeepSeaCorals/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/MarineCadastre/OffshoreWindResourcePotential/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/MarineCadastre/Seagrasses/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/MarineCadastre/Uses/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/dc_slr/BLS_Employees/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/dc_slr/Data_Extent/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/dc_slr/conf_6ft/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/dc_slr/marsh_050/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/dc_slr/marsh_350/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/dc_slr/marsh_450/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/dc_slr/slr_1ft/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/dc_slr/slr_3ft/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coast.noaa.gov/arcgis/services/enow/OceanEconomybyIndicator/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coastalmap.marine.usgs.gov/cmgp/services/National/UnderSeaFeatures/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coastalmap.marine.usgs.gov/cmgp/services/National/coastal_vulnerability_index/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coastalmap.marine.usgs.gov/cmgp/services/National/cvi_WFS/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coastalmap.marine.usgs.gov/cmgp/services/National/slc_Bayes_WFS/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coastalmap.marine.usgs.gov/cmgp/services/National/slc_LongTerm/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coastalmap.marine.usgs.gov/cmgp/services/National/slc_OffshoreBaseline/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coastalmap.marine.usgs.gov/cmgp/services/National/slc_ShortTerm/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://coastalmap.marine.usgs.gov/cmgp/services/National/usSEABED/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://code.google.com/apis/kml/schema/kml21.xsd',
#  'http://code.google.com/apis/kml/schema/kml22gx.xsd',
#  'http://collection.dlese.org',
#  'http://collection.dlese.orghttp://www.dlese.org/Metadata/collection/0.1.01/collection.xsd',
#  'http://conscore.embl.de/webservice/schema/ConScorePrediction.xsd',
#  'http://conscore.embl.de/webservice/schema/ServiceDocumentation.xsd',
#  'http://cosimo.stanford.edu/sdr/metsrights/',
#  'http://data.daff.gov.au/anrdl/resources/schemas/gmd/gmd.xsd',
#  'http://data.daff.gov.au/anrdl/resources/schemas/gml/gml.xsd',
#  'http://data.gios.asu.edu/eml2_1_0/eml.xsd',
#  'http://data.gov.au:80/geoserver/schemas/wfs/2.0/wfs.xsd',
#  'http://data.gov.au:80/geoserver/schemas/wms/1.3.0/capabilities_1_3_0.xsd',
#  'http://data.nanoos.org:80/geoserver/schemas/ows/1.0.0/owsExceptionReport.xsd',
#  'http://data.nodc.noaa.gov/coris/data/CoRIS/fgdc_schema_coris/fgdc-std-001-1998.xsd',
#  'http://data.stadt-salzburg.at/ogdsbg',
#  'http://data.usgs.gov/nggdpp/NGGDPPMetadataSample_v2.xsd',
#  'http://data.wien.gv.at/daten/geo/schemas/ows/1.0.0/owsExceptionReport.xsd',
#  'http://data.wien.gv.at/daten/geo/schemas/wms/1.3.0/exceptions_1_3_0.xsd',
#  'http://data.wien.gv.at/daten/geo/wfs?service=WFS&version=1.1.0&request=DescribeFeatureType&typeName=ogdwien%3AHOEHENLINIEOGD',
#  'http://data.wien.gv.at/daten/geo/wfs?service=WFS&version=1.1.0&request=DescribeFeatureType&typeName=ogdwien%3AMOBPROBLEMSTOFFOGD',
#  'http://data.wien.gv.at/daten/geo/wfs?service=WFS&version=1.1.0&request=DescribeFeatureType&typeName=ogdwien%3ANATURA2TOGD',
#  'http://data.wien.gv.at/daten/geo/wfs?service=WFS&version=1.1.0&request=DescribeFeatureType&typeName=ogdwien%3APROBLEMSTOFFOGD',
#  'http://datacite.org/schema/kernel-2.2',
#  'http://datacite.org/schema/kernel-3',
#  'http://dataconservancy.org/schemas/bop/1.0',
#  'http://dati.provincia.prato.it:80/geoserver/schemas/ows/1.0.0/owsExceptionReport.xsd',
#  'http://dd.eionet.europa.eu/schemas/fgases-2015/FGasesReporting.xsd',
#  'http://dd.eionet.europa.eu/schemas/habides-2.0/derogations.xsd',
#  'http://dd.eionet.europa.eu/schemas/id2011850eu-1.0/AirQualityReporting.xsd',
#  'http://dd.eionet.europa.eu/schemas/inspire-monitoring/monitoring.xsd',
#  'http://dd.eionet.europa.eu/schemas/mmr-pams/MMR_PAMs.xsd',
#  'http://dd.eionet.europa.eu/schemaset/id2011850eu-1.0',
#  'http://demo.mapserver.org/cgi-bin/wfs?SERVICE=WFS&VERSION=1.0.0&REQUEST=DescribeFeatureType&TYPENAME=cities&OUTPUTFORMAT=XMLSCHEMA',
#  'http://demo.mapserver.org/cgi-bin/wfs?SERVICE=WFS&VERSION=1.0.0&REQUEST=DescribeFeatureType&TYPENAME=continents&OUTPUTFORMAT=SFE_XMLSCHEMA',
#  'http://demo.mapserver.org/cgi-bin/wfs?SERVICE=WFS&VERSION=1.0.0&REQUEST=DescribeFeatureType&TYPENAME=continents&OUTPUTFORMAT=XMLSCHEMA',
#  'http://digir.net/schema/conceptual/darwin/2003/1.0',
#  'http://digir.net/schema/conceptual/darwin/2003/1.0/darwin2.xsd',
#  'http://digir.sourceforge.net/schema/conceptual/darwin/2003/1.0/darwin2.xsd',
#  'http://digital.lib.ecu.edu/tei/xsd/tei_P5.xsd',
#  'http://diglib.org/ilsdi/1.1',
#  'http://discomap.eea.europa.eu/arcgis/services/Air/OzoneMonitoring_Dyna_WGS84/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://discomap.eea.europa.eu/arcgis/services/Bio/Biogeographicalregions_Dyna_LAEA/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://discomap.eea.europa.eu/arcgis/services/Bio/CDDA_Dyna_WM/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://discomap.eea.europa.eu/arcgis/services/Bio/Natura2000Hatch_Dyna_LAEA/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://discomap.eea.europa.eu/arcgis/services/Land/CLC1990_Dyna_WM/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://discomap.eea.europa.eu/arcgis/services/Land/CLC2006_Dyna_LAEA/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://discomap.eea.europa.eu/arcgis/services/Land/LandscapeFragmentation_LAEA/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://discomap.eea.europa.eu/arcgis/services/Land/UrbanAtlas_Dyna_WGS84/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://discomap.eea.europa.eu/arcgis/services/Water/NitratesVulnerableZones_Dyna_WGS84/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://discomap.eea.europa.eu/arcgis/services/Water/RiversAndLakesBio_Dyna_WM/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://docs.oasis-open.org/search-ws/',
#  'http://docs.oasis-open.org/security/saml/v2.0/saml-schema-protocol-2.0.xsd',
#  'http://docs.oasis-open.org/wsrf/bf-2.xsd',
#  'http://docs.oasis-open.org/wsrf/rl-2.xsd',
#  'http://docs.oasis-open.org/xacml/2.0/access_control-xacml-2.0-context-schema-os.xsd',
#  'http://docs.oasis-open.org/xacml/2.0/access_control-xacml-2.0-policy-schema-os.xsd',
#  'http://docs.oasis-open.org/xacml/3.0/xacml-1.0-profile-saml2.0-v2-schema-assertion-wd-13.xsd',
#  'http://docs.rioxx.net/schema/v1.0/rioxxterms.xsd',
#  'http://docs.rioxx.net/schema/v1.0/rioxxterms/',
#  'http://docs.rioxx.net/schema/v2.0/rioxxterms.xsd',
#  'http://docs.rioxx.net/schema/v2.0/rioxxterms/',
#  'http://drcwww.uvt.nl/~place/nereus/nereusx.xsd',
#  'http://dublincore.org/architecturewiki/DescriptionSetProfile?action=AttachFile&do=get&target=dcmi-dsp.xsd',
#  'http://dublincore.org/schemas/xmls/qdc/2003/04/02/dc.xsd',
#  'http://dublincore.org/schemas/xmls/qdc/2003/04/02/dcterms.xsd',
#  'http://dublincore.org/schemas/xmls/qdc/2006/01/06/dc.xsd',
#  'http://dublincore.org/schemas/xmls/qdc/2006/01/06/dcterms.xsd',
#  'http://dublincore.org/schemas/xmls/qdc/2008/02/11/dc.xsd',
#  'http://dublincore.org/schemas/xmls/qdc/2008/02/11/dcterms.xsd',
#  'http://dublincore.org/schemas/xmls/qdc/dc.xsd',
#  'http://dublincore.org/schemas/xmls/qdc/dcterms.xsd',
#  'http://dublincore.org/schemas/xmls/simpledc20021212.xsd',
#  'http://dublincore.org/xml/dc-dsp/2008/01/14',
#  'http://eac.staatsbibliothek-berlin.de/schema/cpf.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/AliquotXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/AnalysisFractionXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/AnalysisImageXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/InitialPbModelETXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/InitialPbModelXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/MineralStandardModelXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/MineralStandardUPbModelXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/PbBlankICModelXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/PbBlankXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/PhysicalConstantsModelXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/PhysicalConstantsXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/ReduxMatrixXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/TracerUPbModelXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/TracerXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/ValueModelXMLSchema.xsd',
#  'http://earth-time.org/projects/upb/public_data/XSD/upbReports/ReportSettingsXMLSchema.xsd',
#  'http://earthquake.usgs.gov',
#  'http://earthquake.usgs.gov/eqcenter/shakemap/xml/schemas/shakemap.xsd',
#  'http://earthquake.usgs.gov/shakemap/xml/schemas/shakemap.xsd',
#  'http://echo.nasa.gov/v9/echoforms',
#  'http://ecp.iedadata.org:80/wfs/schemas/ows/1.1.0/owsAll.xsd',
#  'http://ecp.iedadata.org:80/wfs/schemas/wfs/1.0.0/WFS-capabilities.xsd',
#  'http://eden.ign.fr/xsd/isotc211/isofull/20090316/gco/gco.xsd',
#  'http://eden.ign.fr/xsd/isotc211/isofull/20090316/gmd/gmd.xsd',
#  'http://eden.ign.fr/xsd/isotc211/isofull/20090316/gml/gml.xsd',
#  'http://eden.ign.fr/xsd/isotc211/isofull/20090316/gmx/gmx.xsd',
#  'http://eden.ign.fr/xsd/isotc211/isofull/20090316/gsr/gsr.xsd',
#  'http://eden.ign.fr/xsd/isotc211/isofull/20090316/gss/gss.xsd',
#  'http://eden.ign.fr/xsd/isotc211/isofull/20090316/gts/gts.xsd',
#  'http://eden.ign.fr/xsd/isotc211/isofull/20090316/srv/srv.xsd',
#  'http://egisws02.nos.noaa.gov/arcgis/services/Estuarine_Bathymetry/NOAA_Estuarine_Bathymetry/MapServer/WMSServer?version=1.3.0&service=WMS&request=GetSchemaExtension',
#  'http://encdirect.noaa.gov/arcgis/services/MACHC/MICC_ENCview/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://encdirect.noaa.gov/arcgis/services/RNC/NOAA_RNC_Footprints/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://encdirect.noaa.gov/arcgis/services/encdirect/enc_approach/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://encdirect.noaa.gov/arcgis/services/encdirect/enc_berthing/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://encdirect.noaa.gov/arcgis/services/encdirect/enc_coverage/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://encdirect.noaa.gov/arcgis/services/encdirect/enc_general/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://encdirect.noaa.gov/arcgis/services/encdirect/enc_harbour/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://enm.eubrazilopenbio.d4science.org:80/om/omws?xsd=1',
#  'http://enunciate.codehaus.org/schemas/enunciate-1.29.xsd',
#  'http://europass.cedefop.europa.eu/Europass',
#  'http://europass.cedefop.europa.eu/Europass/V2.0',
#  'http://europass.cedefop.europa.eu/xml/EuropassSchema_V2.0.xsd',
#  'http://europass.cedefop.europa.eu/xml/EuropassSchema_V3.0.xsd',
#  'http://eusoils.jrc.ec.europa.eu/WRB/WMS_threats.asp?service=WMS&version=1.3.0&request=GetSchemaExtension',
#  'http://feeds.getmapping.com/ALLOTMENTS_01.wmsx?login=62ec53db-b790-40fc-b069-d3cc7d2f64af&password=q6cd005t&service=WMS&version=1.3.0&request=GetSchemaExtension',
#  'http://fews.wldelft.nl/schemas/version1.0/pi-schemas/pi_timeseries.xsd',
#  'http://fgdcxml.sourceforge.net/schema/fgdc-std-012-2002/fgdc-std-012-2002.xsd',
#  'http://gce-lter.marsci.uga.edu/lter/files/schemas/eml-201/eml.xsd',
#  'http://gce-lter.marsci.uga.edu/public/files/schemas/eml-210/eml.xsd',
#  'http://gce-lter.marsci.uga.edu/public/files/schemas/eml-210/stmml.xsd',
#  'http://gce-lter.marsci.uga.edu/public/files/schemas/project-eml-210/lter-project.xsd',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/dif.xsd',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/dif_v9.4.xsd',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/dif_v9.7.1.xsd',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/dif_v9.8.4.xsd',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/kms/kms.xsd',
#  'http://geo.prgap.org:80/geoserver/schemas/ows/1.1.0/owsAll.xsd',
#  'http://geo.prgap.org:80/geoserver/schemas/wfs/1.0.0/WFS-capabilities.xsd',
#  'http://geo.prgap.org:80/geoserver/schemas/wfs/1.1.0/wfs.xsd',
#  'http://geo4.vic-metria.nu:80/geoserver/schemas/wms/1.3.0/exceptions_1_3_0.xsd',
#  'http://geodata.epa.gov/arcgis/services/OA/SLD_Trans45/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geodata.epa.gov/arcgis/services/OEI/AllWells2015/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geodata.epa.gov/arcgis/services/OEI/FRS_Wastewater/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geodata.epa.gov/arcgis/services/OEI/Factle_Neighborhoods/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geodata.epa.gov/arcgis/services/OSWER/EPA6kQuads/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geodata.nationaalgeoregister.nl/schemas/gml/3.2.1/gml.xsd',
#  'http://geodata.nationaalgeoregister.nl/schemas/ows/1.0.0/owsExceptionReport.xsd',
#  'http://geodata.nationaalgeoregister.nl/schemas/ows/1.1.0/owsAll.xsd',
#  'http://geonexusr.iowadot.gov/arcgis/services/AerialImagery/Aerial_Imagery/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geonexusr.iowadot.gov/arcgis/services/Aviation/Airport_Info/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geonexusr.iowadot.gov/arcgis/services/Construction/Interstate29ConstructionArea/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geonexusr.iowadot.gov/arcgis/services/Construction/Interstate29ConstructionRoads/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geonexusr.iowadot.gov/arcgis/services/Maintenance/ServiceLevel/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geonexusr.iowadot.gov/arcgis/services/Systems_Planning/InterstateCorridorPlan_CrashData/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geonexusr.iowadot.gov/arcgis/services/Systems_Planning/InterstateCorridorPlan_Passenger_NormalizationRating/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geonexusr.iowadot.gov/arcgis/services/Systems_Planning/InterstateCorridorPlan_SUTruckNormalizationRating/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geoportal-geoportail.gc.ca/arcgis/services/Bathymetry_500m_ENG/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geoportal-geoportail.gc.ca/arcgis/services/tides_marees/labels/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geoserv.stat.fi:8080/geoserver/schemas/wfs/1.0.0/WFS-capabilities.xsd',
#  'http://geoserv.stat.fi:8080/geoserver/schemas/wms/1.3.0/capabilities_1_3_0.xsd',
#  'http://geoserv.stat.fi:8080/geoserver/www/inspire/inspire_vs.xsd',
#  'http://geoserver.itc.nl:8080/wps/schemas/wps/1.0.0/wpsGetCapabilities_response.xsd',
#  'http://geosrv:8080/geoserver/schemas/wms/1.3.0/exceptions_1_3_0.xsd',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/CTAeromagneticMap/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/CTAeroradioactivityMap_NY_CT_RI_MA/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/CTAeroradioactivityMap_NewYork_NewEngland/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/CTRadonPotentialMap/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/CTThermalConductivity2_2/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/IABedrockDepth/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/IABoreholeLithIntervals/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/IAHeatPumpFacilities/MapServer/WFSServer?request=DescribeFeatureType%26version=1.1.0%26typename=HeatPumpFacility',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/IAWellHeaders/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/ILBoreholeTemperatures/MapServer/WFSServer?request=DescribeFeatureType%26version=1.1.0%26typename=BoreholeTemperature',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/ILBoreholeTemperatures/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/ILDrillStemTests/MapServer/WFSServer?request=DescribeFeatureType%26version=1.1.0%26typename=DrillStemTest',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/ILWellHeaders/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/ILWellLogs/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/INDevonianGradient/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/INMississippianGradient/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/INPennsylvanianGradient/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/INWellLogs/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/IN_Soil_Horizons_Texture/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/MADirectUseSites/MapServer/WFSServer?request=DescribeFeatureType%26version=1.1.0%26typename=DirectUseSite',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/MADirectUseSites/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/MAHeatFlow1_23/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/MARockChemistry/MapServer/WFSServer?request=DescribeFeatureType%26version=1.1.0%26typename=WRMajorElements',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/MAThermalConductivity/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/MAThermalConductivity2_2/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/MAWellLogs/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/MEAqueousChemistry1_10/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/MEHeatFlow1_23/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/MEWellLogs/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/MIBoreholeLithIntervals/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/MIDrillStemTests/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://geothermal.isgs.illinois.edu/arcgis/services/aasggeothermal/MIWellLogs/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
# ...
#  'http://lipas.cc.jyu.fi:80/geoserver/schemas/ows/1.0.0/owsExceptionReport.xsd',
#  'http://localhost:8080/geoserver/schemas/gml/2.1.2.1/feature.xsd',
#  'http://localhost:9090/geoserver/ogdsbg/wfs?service=WFS&version=1.1.0&request=DescribeFeatureType&typeName=ogdsbg%3Abpl_aufbaustufe',
#  'http://localhost:9090/geoserver/ogdsbg/wfs?service=WFS&version=1.1.0&request=DescribeFeatureType&typeName=ogdsbg%3Awahlsprengel',
#  'http://localhost:9090/geoserver/schemas/ows/1.0.0/owsExceptionReport.xsd',
#  'http://localhost:9090/geoserver/schemas/wfs/1.1.0/wfs.xsd',
#  'http://localview.broxtowe.gov.uk/arcgis/services/INSPIRE/BroxtoweINSPIREAnnexIII/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://map.gsa.state.al.us/ogbmaps/services/OGB/base/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://map.gsa.state.al.us/ogbmaps/services/OneGeology/GSA_EN_SURFICIAL_GEOLOGY/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://mapping.broxbourne.gov.uk:80/geoserver/schemas/ows/1.0.0/owsExceptionReport.xsd',
#  'http://mapping.launceston.tas.gov.au:80/arcgis/services/Public/DetailSurvey/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.aims.gov.au/geoserver/schemas/wms/1.3.0/exceptions_1_3_0.xsd',
#  'http://maps.bristol.gov.uk/WMS/INSPIRE/Core/MapServer/WMSServer?version=1.3.0&service=WMS&request=GetSchemaExtension',
#  'http://maps.carlisle.gov.uk/getows.ashx?service=wfs&version=1.0.0&SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=allotments&OUTPUTFORMAT=XMLSCHEMA',
#  'http://maps.carlisle.gov.uk/getows.ashx?service=wfs&version=1.0.0&SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=smoke_control_zones&OUTPUTFORMAT=XMLSCHEMA',
#  'http://maps.communities.gov.uk:80/geoserver/schemas/wms/1.3.0/capabilities_1_3_0.xsd',
#  'http://maps.ngdc.noaa.gov/arcgis/services/Sample_Index/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/etopo1/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/firedetects/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/gebco08_hillshade/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/hot_springs/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/bag_hillshades/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/crm_hillshade/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/dem_extents/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/dem_hillshades/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/etopo1_hillshade/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/fishmaps/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/hazards/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/marine_geology/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/marine_geology_dynamic/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/multibeam/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/multibeam_dynamic/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/nos_hydro/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/nos_hydro_dynamic/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/nos_seabed/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/sample_index_dynamic/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/seafloor_age/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/trackline_all_parameters/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/trackline_bathymetry/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/trackline_combined_dynamic/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/trackline_gravity/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/trackline_magnetics/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.ngdc.noaa.gov/arcgis/services/web_mercator/trackline_single_channel_seismics/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.northlincs.gov.uk/geoserver/schemas/wfs/1.0.0/WFS-capabilities.xsd',
#  'http://maps.sco.wisc.edu/cgi-bin/fullwfs3.pl?service=wfs&version=1.0.0&request=DescribeFeatureType',
#  'http://maps.sco.wisc.edu/schemas/gc_uml20051216.xsd',
#  'http://maps.york.gov.uk/arcgis/services/Basemaps/WMS_basemaps/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.york.gov.uk/arcgis/services/Public/INSPIRE/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.york.gov.uk/arcgis/services/Public/LV_EnvPlanPlanning_Uniform/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps.york.gov.uk/arcgis/services/Public/LV_EnvPlanPlanning_gisdb/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maps2.dcgis.dc.gov/dcgis/services/DCGIS_DATA/Ortho2012_WebMercator/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://mapserver.gis.umn.edu/mapserver',
#  'http://mapserver.kansasgis.org/arcgis/services/NGDS/KSBoreholeTemperatures/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://mapserver.kansasgis.org/arcgis/services/NGDS/KSWellTests/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://mapserver.kansasgis.org/arcgis/services/NGDS/KS_SURFACE_GEOLOGY/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maritimeboundaries.noaa.gov/arcgis/services/Hydrographic_Services/Planned_Survey_Areas/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maritimeboundaries.noaa.gov/arcgis/services/MaritimeBoundaries/US_Maritime_Limits_Boundaries/MapServer/WMSServer?version=1.3.0&service=WMS&request=GetSchemaExtension',
#  'http://maritimeboundaries.noaa.gov/arcgis/services/encdirect/enc_general/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maritimeboundaries.noaa.gov/arcgis/services/encdirect/enc_harbour/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maritimeboundaries.noaa.gov/arcgis/services/encdirect/enc_overview/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://maury.marine.unc.edu/cgi-bin/mapserv?map=/opt/secoora_ogc/maps/secoora_insitu.map&SERVICE=WFS&VERSION=1.0.0&REQUEST=DescribeFeatureType&TYPENAME=adcp_vectors,drifter_vectors,sea_surface_currents&OUTPUTFORMAT=XMLSCHEMA',
#  'http://maury.marine.unc.edu/cgi-bin/mapserv?map=/opt/secoora_ogc/maps/secoora_insitu.map&SERVICE=WFS&VERSION=1.0.0&REQUEST=DescribeFeatureType&TYPENAME=air_temperature_obs_hourly_recent&OUTPUTFORMAT=XMLSCHEMA',
#  'http://maury.marine.unc.edu/cgi-bin/mapserv?map=/opt/secoora_ogc/maps/secoora_insitu.map&SERVICE=WFS&VERSION=1.0.0&REQUEST=DescribeFeatureType&TYPENAME=salinity_obs_hourly_recent&OUTPUTFORMAT=XMLSCHEMA',
#  'http://maury.marine.unc.edu/cgi-bin/mapserv?map=/opt/secoora_ogc/maps/secoora_insitu.map&SERVICE=WFS&VERSION=1.0.0&REQUEST=DescribeFeatureType&TYPENAME=water_level_obs_hourly_recent&OUTPUTFORMAT=XMLSCHEMA',
#  'http://maury.marine.unc.edu/cgi-bin/mapserv?map=/opt/secoora_ogc/maps/secoora_insitu.map&SERVICE=WFS&VERSION=1.0.0&REQUEST=DescribeFeatureType&TYPENAME=wind_obs_hourly_recent&OUTPUTFORMAT=XMLSCHEMA',
#  'http://maven.apache.org/POM/4.0.0',
#  'http://maven.apache.org/SETTINGS/1.0.0',
#  'http://maven.apache.org/maven-v4_0_0.xsd',
#  'http://maven.apache.org/plugins/maven-archetype-plugin/archetype-catalog/1.0.0',
#  'http://maven.apache.org/xsd/archetype-catalog-1.0.0.xsd',
#  'http://maven.apache.org/xsd/maven-4.0.0.xsd',
#  'http://maven.apache.org/xsd/settings-1.0.0.xsd',
#  'http://metadata/published/xsd/schema.xsd',
#  'http://mgs.geology.wmich.edu/arcgis/services/MIAqueousChemistry1_10/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://mgs.geology.wmich.edu/arcgis/services/MIGS_Michigan_Geology/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://mgs.geology.wmich.edu/arcgis/services/MIWellLogs/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://moimagery.missouri.edu/arcgis/services/Joplin/Joplin_2ft/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://moimagery.missouri.edu/arcgis/services/Joplin/Joplin_building/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://moimagery.missouri.edu/arcgis/services/LIDAR/MO_mosaic/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://moimagery.missouri.edu/arcgis/services/Map/Census_Tracts2010/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://moimagery.missouri.edu/arcgis/services/Map/Doqq2008_utm/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://moimagery.missouri.edu/arcgis/services/Map/LandCover2005/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://moimagery.missouri.edu/arcgis/services/Map/NAIP2012/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://mook.inf.ed.ac.uk:8848/SedMLWebService/sedmlws?xsd=1',
#  'http://mrdata.usgs.gov/services/ds898?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=domains&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/services/ds898?service=WMS&version=1.3.0&request=GetSchemaExtension',
#  'http://mrdata.usgs.gov/services/nmra?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=Porphyry_Cu&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/services/surveys?service=WMS&version=1.3.0&request=GetSchemaExtension',
#  'http://mrdata.usgs.gov/wfs/active-mines?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=mineplant&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/agdb2?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=agdb&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/akages-geo?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=akages&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/akgeol?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=akgeol,akfault&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/ardf?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=ardf&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/asbestos?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=asbestos&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/copper-smelters?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=cusmelters&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/digitized?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=digitized,digital&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/ds801?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=ds801&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/geochron?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=geochron&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/hi?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=units,faults,dikes&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/kb?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=Geology,Faults&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/mrds?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=mrds&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/ngdbrock?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=ngdbrock&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/ngs?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=natgeochem&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/nicrpge?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=nicrpge&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/nuresed?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=nuresed&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://mrdata.usgs.gov/wfs/nurewtr?SERVICE=WFS&VERSION=1.1.0&REQUEST=DescribeFeatureType&TYPENAME=nurewtr&OUTPUTFORMAT=text/xml;%20subtype=gml/3.1.1',
#  'http://myosg.grid.iu.edu/schema/rgsummary.xsd',
#  'http://naca.central.cranfield.ac.uk/ethos-oai/2.0/',
#  'http://naca.central.cranfield.ac.uk/ethos-oai/2.0/uketd_dc.xsd',
#  'http://naesb.org/espi',
#  'http://namespace.emotion-project.eu/version/Final2.1.0/pubtrans',
#  'http://ngamaps.geointapps.org:80/arcgis/services/NEPAL/Landslide_Inventory_2_May_2015/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://ngamaps.geointapps.org:80/arcgis/services/NEPAL/NGA_routes/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://ngamaps.geointapps.org:80/arcgis/services/NEPAL/Nepal_Information_Apollo/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://ngamaps.geointapps.org:80/arcgis/services/NEPAL/Nepal_Landslide_Potential_Model_May18_May22/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://ngdc.noaa.gov/metadata/published/xsd/ngdcSchema/schema.xsd',
#  'http://ngdc.noaa.gov/metadata/published/xsd/schema.xsd',
#  'http://ngdc.noaa.gov/mgg/ecs/metadata/seismic/xml/seismicMetadata.xsd',
#  'http://nis.lternet.edu/schemas/EML/eml-2.1.0/eml.xsd',
#  'http://nis.lternet.edu/schemas/EML/eml-2.1.0/stmml.xsd',
#  'http://noise.discomap.eea.europa.eu/arcgis/services/Noise/2012_NOISE_END_LAEA_Major_Airports/MapServer/WmsServer?version=1.3.0%26service=WMS%26request=GetSchemaExtension',
#  'http://nrg.wustl.edu/arc',
#  ...]

# %% [markdown]
# From our unique, space-delimited list, we have **2,366 strings**. Not all of them refer to externally resolvable objects, ie they are relative paths, FTP links, etc. File names or relative paths: **363** (15% of the unpacked strings).
#
# A note on schemas and XML validation.
#
# Command line validation tools such as the [Apache Xerces PParse](http://xml.apache.org/xerces-c-new/pparse.html) require that the schema(s) be included in the XML. So there's no option to point to a schema URL or file at run time. A schema reference needs to be injected into the XML before executing PParse.
#
# This is also true of more integrated platforms, such as Oxygen. You need to assign a schema to an XML document before it can validate. This action inserts the reference as @schemaLocation or @noNamespaceSchemaLocation.
#
# So you need the reference *in* the XML for validation. But it doesn't need to be a URL.
#
# It isn't uncommon, when developing a schema or an XML document, to point to a local XSD for validation. It is often faster (XML validation against the externally-hosted schemas has some fairly significant latency - response times of seconds.)
#
# The issue is when the XML is then published through some platform without the local path changed to some appropriate URL. Those files can't be validated without modification, injecting a schema reference, and it isn't always clear which schema should be used. In addition, schemas do change over time so it's important that the reference match that used for the document at the time of publication - otherwise a newer or simply different schema reference might be injected and the validation process returns errors.
#
# And we can see, in these sets, different versions of the schemas identified in the URLs.

# %%
# federally hosted schemas
with open('outputs/federal_schemas_sorted.txt', 'r') as f:
    federal_schemas = [s.strip() for s in f.readlines() if s]

federal_schemas
# Out:
# ['ftp://ftp.ncbi.nlm.nih.gov/pubchem/specifications/pubchem.xsd',
#  'ftp://ftp.ncddc.noaa.gov/pub/Metadata/Online_ISO_Training/Intro_to_ISO/schemas/ISObio/schema.xsd',
#  'http://api.echo.nasa.gov/echo/wsdl/EchoForms.xsd',
#  'http://aviationweather.gov/adds/schema/aircraftreport1_0.xsd',
#  'http://aviationweather.gov/adds/schema/airsigmet1_1.xsd',
#  'http://aviationweather.gov/adds/schema/gairmet1_0.xsd',
#  'http://aviationweather.gov/adds/schema/pirep1_2.xsd',
#  'http://aviationweather.gov/adds/schema/taf1_2.xsd',
#  'http://data.nodc.noaa.gov/coris/data/CoRIS/fgdc_schema_coris/fgdc-std-001-1998.xsd',
#  'http://data.usgs.gov/nggdpp/NGGDPPMetadataSample_v2.xsd',
#  'http://earthquake.usgs.gov/eqcenter/shakemap/xml/schemas/shakemap.xsd',
#  'http://earthquake.usgs.gov/shakemap/xml/schemas/shakemap.xsd',
#  'http://echo.nasa.gov/v9/echoforms',
#  'http://fgdcxml.sourceforge.net/schema/fgdc-std-012-2002/fgdc-std-012-2002.xsd',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/dif.xsd',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/dif_v9.4.xsd',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/dif_v9.7.1.xsd',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/dif/dif_v9.8.4.xsd',
#  'http://gcmd.gsfc.nasa.gov/Aboutus/xml/kms/kms.xsd',
#  'http://graphical.weather.gov/xml/DWMLgen/schema/DWML.xsd',
#  'http://graphical.weather.gov/xml/DWMLgen/schema/meta_data.xsd',
#  'http://hesapi.lbl.gov/mf_api/xsd/add_lu_schedule_obj',
#  'http://hesapi.lbl.gov/mf_api/xsd/calculate',
#  'http://hesapi.lbl.gov/mf_api/xsd/nearest_weather',
#  'http://hesapi.lbl.gov/mf_api/xsd/retrieve_results',
#  'http://hesapi.lbl.gov/mf_api/xsd/retrofit',
#  'http://hesapi.lbl.gov/mf_api/xsd/submit_dhw_water_heater',
#  'http://hesapi.lbl.gov/st_api/xsd/archive_buildings_by_id',
#  'http://hesapi.lbl.gov/st_api/xsd/building_ca_id',
#  'http://hesapi.lbl.gov/st_api/xsd/calc_energy_multi',
#  'http://hesapi.lbl.gov/st_api/xsd/calculate',
#  'http://hesapi.lbl.gov/st_api/xsd/delete_buildings_by_id',
#  'http://hesapi.lbl.gov/st_api/xsd/doe2sim',
#  'http://hesapi.lbl.gov/st_api/xsd/export_label_results',
#  'http://hesapi.lbl.gov/st_api/xsd/generate_label',
#  'http://hesapi.lbl.gov/st_api/xsd/login_lbl',
#  'http://hesapi.lbl.gov/st_api/xsd/register_qa',
#  'http://hesapi.lbl.gov/st_api/xsd/retrieve_buildings_by_address',
#  'http://hesapi.lbl.gov/st_api/xsd/retrieve_buildings_by_id',
#  'http://hesapi.lbl.gov/st_api/xsd/retrieve_extended_results',
#  'http://hesapi.lbl.gov/st_api/xsd/retrieve_inputs',
#  'http://hesapi.lbl.gov/st_api/xsd/retrieve_label_results',
#  'http://hesapi.lbl.gov/st_api/xsd/retrieve_legacy_buildings',
#  'http://hesapi.lbl.gov/st_api/xsd/retrieve_recommendations',
#  'http://hesapi.lbl.gov/st_api/xsd/user_exists',
#  'http://isis.astrogeology.usgs.gov/Schemas/Application/application.xsd',
#  'http://isis.astrogeology.usgs.gov/Schemas/Documentation/documentation.xsd',
#  'http://lcweb2.loc.gov/mets/Schemas/AMD.xsd',
#  'http://lcweb2.loc.gov/mets/Schemas/VMD.xsd',
#  'http://leisp.usdoj.gov/niem/FoiaAnnualReport/exchange/1.02',
#  'http://leisp.usdoj.gov/niem/FoiaAnnualReport/exchange/1.03',
#  'http://ngdc.noaa.gov/metadata/published/xsd/ngdcSchema/schema.xsd',
#  'http://ngdc.noaa.gov/metadata/published/xsd/schema.xsd',
#  'http://ngdc.noaa.gov/mgg/ecs/metadata/seismic/xml/seismicMetadata.xsd',
#  'http://nssdc.gsfc.nasa.gov/schema/astro_mission.xsd',
#  'http://nvd.nist.gov/schema/configuration_0.1.xsd',
#  'http://nvd.nist.gov/schema/nvd-cce-feed_0.1.xsd',
#  'http://nvd.nist.gov/schema/scap-core_0.3.xsd',
#  'http://pds.jpl.nasa.gov/pds4/pds/v1/PDS4_PDS_1101.xsd',
#  'http://pds.jpl.nasa.gov/pds4/pds/v1/PDS4_PDS_1201.xsd',
#  'http://pds.jpl.nasa.gov/pds4/pds/v1/PDS4_PDS_1301.xsd',
#  'http://pds.jpl.nasa.gov/pds4/pds/v1/PDS4_PDS_1400.xsd',
#  'http://pds.jpl.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1000.xsd',
#  'http://pds.jpl.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1101.xsd',
#  'http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1100/dph_example_archive_VG2PLS/xml_schema/PDS4_PDS_1100.xsd',
#  'http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1100/dph_example_products/xml_schema/PDS4_PDS_1100.xsd',
#  'http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1101/dph_example_archive_VG2PLS/xml_schema/PDS4_PDS_1101.xsd',
#  'http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1101/dph_example_products/xml_schema/PDS4_PDS_1101.xsd',
#  'http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1101/dph_example_products/xml_schema/dph_example_dict_1101.xsd',
#  'http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1200/dph_example_archive_VG2PLS/xml_schema/PDS4_PDS_1200.xsd',
#  'http://pds.jpl.nasa.gov/repository/pds4/examples/dph_examples_1200/dph_example_products/xml_schema/PDS4_PDS_1200.xsd',
#  'http://pds.jpl.nasa.gov/repository/pds4/examples/test_0100/PDS4_PDS_1000.xsd',
#  'http://pds.jpl.nasa.gov/repository/pds4/examples/test_0100/dph_example_dict_0100.xsd',
#  'http://pds.nasa.gov/pds4/disp/v1',
#  'http://pds.nasa.gov/pds4/disp/v1/PDS4_DISP_1301.xsd',
#  'http://pds.nasa.gov/pds4/dph/v01',
#  'http://pds.nasa.gov/pds4/mission/mvn/v1',
#  'http://pds.nasa.gov/pds4/mvn/v1/PDS4_MVN_1000.xsd',
#  'http://pds.nasa.gov/pds4/mvn/v1/PDS4_MVN_1011.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1',
#  'http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1000.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1100.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1101.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1200.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1300.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1301.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1400.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1410.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1500.xsd',
#  'http://pds.nasa.gov/pds4/pds/v1\\thttp://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1100.xsd',
#  'http://pds.nasa.gov/pds4/phxmd/v02',
#  'http://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1000.xsd',
#  'http://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1100.xsd',
#  'http://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1101.xsd',
#  'http://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1201.xsd',
#  'http://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1300.xsd',
#  'http://pds.nasa.gov/pds4/schema/released/pds/v1/PDS4_PDS_1400.xsd',
#  'http://pds.nasa.gov/pds4/sp/v1',
#  'http://pubchem.ncbi.nlm.nih.gov.libproxy.lib.unc.edu/hierarchy_data',
#  'http://pubchem.ncbi.nlm.nih.gov.libproxy.lib.unc.edu/pug_rest',
#  'http://pubchem.ncbi.nlm.nih.gov.libproxy.lib.unc.edu/pug_rest/hierarchy_data.xsd',
#  'http://pubchem.ncbi.nlm.nih.gov.libproxy.lib.unc.edu/pug_rest/pug_rest.xsd',
#  'http://pubchem.ncbi.nlm.nih.gov/hierarchy_data',
#  'http://pubchem.ncbi.nlm.nih.gov/pug_rest',
#  'http://pubchem.ncbi.nlm.nih.gov/pug_rest/hierarchy_data.xsd',
#  'http://pubchem.ncbi.nlm.nih.gov/pug_rest/pug_rest.xsd',
#  'http://purl.lanl.gov/STB-RL/schemas/2003-09/DII.xsd',
#  'http://purl.lanl.gov/STB-RL/schemas/2004-11/DIDL.xsd',
#  'http://scap.nist.gov/schema/configuration/0.1',
#  'http://scap.nist.gov/schema/feed/configuration/0.1',
#  'http://search.ams.usda.gov/FarmersMarkets/v1/data.svc?xsd=xsd0',
#  'http://search.ams.usda.gov/FarmersMarkets/v1/data.svc?xsd=xsd1',
#  'http://search.ams.usda.gov/FarmersMarkets/v1/data.svc?xsd=xsd2',
#  'http://spaseql.gsfc.nasa.gov/schema/spaseql_query.xsd',
#  'http://starbase.jpl.nasa.gov/pds4/1201/dph_examples_20140625/dph_example_archive_VG2PLS/xml_schema/PDS4_PDS_1201.xsd',
#  'http://starbase.jpl.nasa.gov/pds4/1201/dph_examples_20140625/dph_example_archive_VG2PLS/xml_schema/dph_example_dict_1201.xsd',
#  'http://starbase.jpl.nasa.gov/pds4/1201/dph_examples_20140625/dph_example_products/xml_schema/PDS4_PDS_1201.xsd',
#  'http://starbase.jpl.nasa.gov/pds4/1201/dph_examples_20140625/dph_example_products/xml_schema/dph_example_dict_1201.xsd',
#  'http://starbase.jpl.nasa.gov/pds4/1300/dph_example_archive_VG2PLS/xml_schema/PDS4_PDS_1300.xsd',
#  'http://starbase.jpl.nasa.gov/pds4/1300/dph_example_archive_VG2PLS/xml_schema/dph_example_dict_1300.xsd',
#  'http://starbase.jpl.nasa.gov/pds4/1300/dph_example_products/xml_schema/PDS4_PDS_1300.xsd',
#  'http://starbase.jpl.nasa.gov/pds4/1300/dph_example_products/xml_schema/dph_example_dict_1300.xsd',
#  'http://starbase.jpl.nasa.gov/pds4/1400/dph_example_products/xml_schema/dph_example_dict_1400.xsd',
#  'http://stategeothermaldata.org/uri-gin/aasg/xmlschema/welllog/0.8',
#  'http://water.usgs.gov/GIS/metadata/usgswrd/fgdc-std-001-1998.xsd',
#  'http://waterservices.usgs.gov/WaterML-1.1.xsd',
#  'http://waterservices.usgs.gov/WaterML-1.2.xsd',
#  'http://weather.gov/ohd/hydroxc/schemas/hydrogen/HydroGenData.xsd',
#  'http://www.csc.noaa.gov/ioos/schema',
#  'http://www.digitalpreservation.gov:/formats/schemas/fdd/v1/htmlTypes.xsd',
#  'http://www.fgdc.gov/framework/geodeticControl',
#  'http://www.fgdc.gov/metadata/fgdc-std-001-1998.xsd',
#  'http://www.fgdc.gov/schemas/metadata/fgdc-std-001-1998.xsd',
#  'http://www.imsglobal.org/xsd/ims_xlink.xsd',
#  'http://www.loc.gov./standards/mets/mets.xsd',
#  'http://www.loc.gov/AMD/',
#  'http://www.loc.gov/MARC21/slim',
#  'http://www.loc.gov/METS/',
#  'http://www.loc.gov/METS_Profile/',
#  'http://www.loc.gov/METS_Profile/v2',
#  'http://www.loc.gov/VMD/',
#  'http://www.loc.gov/audioMD/',
#  'http://www.loc.gov/ead/ead.xsd',
#  'http://www.loc.gov/mads/mads.xsd',
#  'http://www.loc.gov/mets/mets.xsd',
#  'http://www.loc.gov/mix/',
#  'http://www.loc.gov/mix/mix.xsd',
#  'http://www.loc.gov/mix/mix02.xsd',
#  'http://www.loc.gov/mix/v20',
#  'http://www.loc.gov/mods/',
#  'http://www.loc.gov/mods/v3',
#  'http://www.loc.gov/mods/v3/mods-3-1.xsd',
#  'http://www.loc.gov/standards/amdvmd/audioMD.xsd',
#  'http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd',
#  'http://www.loc.gov/standards/mets/mets.xsd',
#  'http://www.loc.gov/standards/mets/profile_docs/mets.profile.v1-2.xsd',
#  'http://www.loc.gov/standards/mets/profile_docs/mets.profile.v2-0.xsd',
#  'http://www.loc.gov/standards/mets/version16/mets.v1-6.xsd',
#  'http://www.loc.gov/standards/mets/version17/mets.v1-7.xsd',
#  'http://www.loc.gov/standards/mets/xlink.xsd',
#  'http://www.loc.gov/standards/mix/',
#  'http://www.loc.gov/standards/mix/mix.xsd',
#  'http://www.loc.gov/standards/mix/mix02.xsd',
#  'http://www.loc.gov/standards/mix/mix20/mix20.xsd',
#  'http://www.loc.gov/standards/mods/mods.xsd',
#  'http://www.loc.gov/standards/mods/v3/mods-3-0.xsd',
#  'http://www.loc.gov/standards/mods/v3/mods-3-1.xsd',
#  'http://www.loc.gov/standards/mods/v3/mods-3-2.xsd',
#  'http://www.loc.gov/standards/mods/v3/mods-3-3.xsd',
#  'http://www.loc.gov/standards/mods/v3/mods-3-4.xsd',
#  'http://www.loc.gov/standards/mods/xlink.xsd',
#  'http://www.loc.gov/standards/premis',
#  'http://www.loc.gov/standards/premis/',
#  'http://www.loc.gov/standards/premis/PREMIS-v1-0.xsd',
#  'http://www.loc.gov/standards/premis/premis.xsdhttp://pds.nasa.gov/pds4/pds/v1/PDS4_PDS_1201.xsd',
#  'http://www.loc.gov/standards/premis/v1',
#  'http://www.loc.gov/standards/premis/v1/PREMIS-v1-1.xsd',
#  'http://www.loc.gov/standards/premis/v2/premis-v2-0.xsd',
#  'http://www.loc.gov/standards/premis/v2/premis.xsd',
#  'http://www.loc.gov/standards/rights/METSRights.xsd',
#  'http://www.loc.gov/standards/sru/sru1-1archive/xml-files/srw-types.xsd',
#  'http://www.loc.gov/standards/textMD/textMD-v3.01a.xsd',
#  'http://www.loc.gov/standards/xlink/xlink.xsd',
#  'http://www.loc.gov/zing/srw/',
#  'http://www.ncbi.nlm.nih.gov',
#  'http://www.ncbi.nlm.nih.gov.libproxy.lib.unc.edu',
#  'http://www.ncbi.nlm.nih.gov/viewvc/v1/trunk/sra/doc/SRA_1-5/SRA.analysis.xsd?view=co',
#  'http://www.ncbi.nlm.nih.gov/viewvc/v1/trunk/sra/doc/SRA_1-5/SRA.experiment.xsd?view=co',
#  'http://www.ncbi.nlm.nih.gov/viewvc/v1/trunk/sra/doc/SRA_1-5/SRA.run.xsd?view=co',
#  'http://www.ngdc.noaa.gov/metadata/published/xsd/ngdcSchema/schema.xsd',
#  'http://www.ngdc.noaa.gov/metadata/published/xsd/schema.xsd',
#  'http://www.ngdc.noaa.gov/metadata/published/xsd/schema/gmd/gmd.xsd',
#  'http://www.ngdc.noaa.gov/metadata/published/xsd/schema/gmi',
#  'http://www.ngdc.noaa.gov/mgg/ecs/metadata/seismic/xml/seismicMetadata.xsd',
#  'http://www.nws.noaa.gov/forecasts/xml/DWMLgen/schema/DWML.xsd',
#  'http:/hdfeos.gsfc.nasa.gov/Schema/bmgt/collection_valids.xsd',
#  'http:/hdfeos.gsfc.nasa.gov/Schema/bmgt/granule_valids.xsd',
#  'https://ndar.nih.gov:443/DataDictionary/dataDictionary?xsd=1',
#  'https://ndar.nih.gov:443/DataManager/dataManager?xsd=1',
#  'https://starbase.jpl.nasa.gov/pds4/1400/dph_example_archive_VG2PLS/xml_schema/dph_example_dict_1400.xsd',
#  'https://starbase.jpl.nasa.gov/pds4/1400/dph_example_products/xml_schema/PDS4_PDS_1400.xsd',
#  'https://starbase.jpl.nasa.gov/pds4/1400/dph_example_products/xml_schema/dph_example_dict_1400.xsd',
#  'https://www.fgdc.gov/schemas/metadata/fgdc-std-001-1998.xsd']

# %% [markdown]
# **206 identified as federally-hosted schemas**

# %%
# linkrot in the set of unique schema URLs (post-split)
sql = """
select round(status_code, -2) as code,
	count(round(status_code, -2)) as num
from schema_status
group by code
order by code;
"""

df = pd.read_sql(sql, engine)
df
# with pd.option_context('display.max_colwidth', 1000):
#     display(df[:10])

# %%
# as a percent of the total number of schemas (2365 unique items)
sql = """
select round(status_code, -2) as code,
	round(count(round(status_code, -2)) / 2365. * 100.0, 2) as pct
from schema_status
group by code
order by code;
"""

df = pd.read_sql(sql, engine)
df
# Out:
#    code    pct
# 0   200  37.59
# 1   300  15.69
# 2   400  20.63
# 3   500   3.64
# 4   900  22.45

# %% [markdown]
# Only 53% are accessible (bearing in mind that 300 of the 900s are local references so not resolvable anyway).
#
# Let's run a round of counting for federally-hosted ones.
#
# (Just to note, we care about those, some of them more than others, because they are so commonly linked to in the EO-related metadata. While the ISO schemas are hosted on a non-fed server, for a long time, that system didn't include a root schema to link the set together for use in something like PParse. One of the NGDC schemas served as this root schema. Also, during the rounds of FGDC to ISO updates, examples XSLTs for that process were shared within the community. Those XSLTs often contained an NGDC schema reference so that became a default.)

# %%
from collections import defaultdict
from math import floor, ceil

with open('outputs/federal_schema_linkrot.csv', 'r') as f:
    fschemas = [s.strip().split(',') for s in f.readlines() if s.strip()]

fed_stats = defaultdict(int)
for schema, status, vdate in fschemas:
    code = floor(int((int(status) / 100.)) * 100)
    fed_stats[code] += 1
    
for k, v in fed_stats.iteritems():
    print '{0}: {1} schemas'.format(k, v)
# Out:
# 200.0: 98 schemas
# 400.0: 16 schemas
# 900.0: 12 schemas
# 300.0: 78 schemas

# %% [markdown]
# These aren't as likely to be unavailable. (The chunk of redirects is almost entirely due to two systems, each with a large number of schemas referenced, multiple versions, etc.)
